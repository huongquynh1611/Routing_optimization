# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\tlhqu\anaconda3\lib\site-packages (2.4)
# Requirement already satisfied: amply>=0.1.2 in c:\users\tlhqu\anaconda3\lib\site-packages (from pulp) (0.1.4)
# Requirement already satisfied: pyparsing in c:\users\tlhqu\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (2.4.7)
# Requirement already satisfied: docutils>=0.3 in c:\users\tlhqu\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (0.16)

# %%
from pulp import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
#a handful of sites
sites = ['Barcelona','Belgrade','Berlin','Brussels','Bucharest','Budapest','Copenhagen','Dublin','Hamburg','Istanbul','Kiev','London','Madrid','Milan','Moscow','Munich','Paris','Prague','Rome','Saint Petersburg','Sofia','Stockholm','Vienna','Warsaw']
sites = sites[0:10]
# sites = ['Barcelona','Belgrade','Berlin','Brussels','Bucharest','Budapest','Copenhagen']
latlng = ['latitude', 'longitude']
position = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\position.csv', index_col="City")
flighttime = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\flight_time.csv', index_col="City")
distance = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\distance.csv', index_col="City")
position.head(5)
print(len(sites))
# Out:
# 10

# %%
#make some positions (so we can plot this)
positions = dict( ( city, (position.loc[city, 'longitude'], position.loc[city, 'latitude']) ) for city in sites)

# %%
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.gca().axis('off');

# %%
# get distanc between cities
distances = dict( ((s1,s2), distance.loc[s1, s2] ) for s1 in positions for s2 in positions if s1!=s2)

# %% [markdown]
# ## The model
#
# With a few modifications, the original traveling salesman problem can support multiple salesman. Instead of making each facility only be visited once, the origin facility will be visited multiple times. If we have two salesman then the origin is visited exactly twice and so on.
#
# For **K** vehicles or sales people:
#
# ### Variables:
#
# $x_{ij}=
# \begin{cases}
# 1: \text{the path goes from city i to j}\\
# 0: \text{otherwise}
# \end{cases}$
#
# ### order dummy variables:
#
# $u_i - u_j + C*x_{ij} \leq C - d_j, C = N/K$
# $\begin{cases}
# u_i: \text{order that site i is visited}\\
# d_j: \text{the cost to visit city j}, 0 \leq u_i \leq C - d_j, \forall i \in V \setminus \{0\}
# \end{cases}$
#
# ### Goal:
#
# $min\sum_{i=0}^{n}\sum_{j\neq{i}, j=0}^{n}{c_{ij}}{x_{ij}}$
# $\begin{cases}
# c_{ij}: \text{distance from city i to city j}\\
# x_{ij}: \text{whether there's a path between i and j}
# \end{cases}$
#
# ### Constraints:
#
# $\sum_{i\in{V}}{x_{ij} = 1}, \forall j \in V \setminus \{0\}$
#
# $\sum_{j\in{V}}{x_{ij} = 1}, \forall i \in V \setminus \{0\}$
#
# $\sum_{i\in{V}}{x_{i0} = K}$
#
# $\sum_{j\in{V}}{x_{0j} = K}$

# %%
K = 3 #the number of sales people

# %%
#create the problme
prob=LpProblem("vehicle", LpMinimize)

# %%
#indicator variable if site i is connected to site j in the tour
x = LpVariable.dicts('x',distances,0,1,LpBinary)
print(len(x))
#dummy vars to eliminate subtours
u = LpVariable.dicts('u', sites, 0, len(sites)-1, LpInteger)
print(u)
# Out:
# 90
# {'Barcelona': u_Barcelona, 'Belgrade': u_Belgrade, 'Berlin': u_Berlin, 'Brussels': u_Brussels, 'Bucharest': u_Bucharest, 'Budapest': u_Budapest, 'Copenhagen': u_Copenhagen, 'Dublin': u_Dublin, 'Hamburg': u_Hamburg, 'Istanbul': u_Istanbul}

# %%
#the objective
cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
prob+=cost

# %%
#constraints
for k in sites:
    cap = 1 if k != 'Berlin' else K
    #inbound connection
    prob+= lpSum([ x[(i,k)] for i in sites if (i,k) in x]) ==cap
    #outbound connection
    prob+=lpSum([ x[(k,i)] for i in sites if (k,i) in x]) ==cap
    
#subtour elimination
N=len(sites)/K
for i in sites:
    for j in sites:
        if i != j and (i != 'Berlin' and j!= 'Berlin') and (i,j) in x:
            prob += u[i] - u[j] <= (N)*(1-x[(i,j)]) - 1
print(prob)
# Out:
# vehicle:
# MINIMIZE
# 1528.13*x_('Barcelona',_'Belgrade') + 1497.61*x_('Barcelona',_'Berlin') + 1062.89*x_('Barcelona',_'Brussels') + 1968.42*x_('Barcelona',_'Bucharest') + 1498.79*x_('Barcelona',_'Budapest') + 1757.54*x_('Barcelona',_'Copenhagen') + 1469.29*x_('Barcelona',_'Dublin') + 1471.78*x_('Barcelona',_'Hamburg') + 2230.42*x_('Barcelona',_'Istanbul') + 1528.13*x_('Belgrade',_'Barcelona') + 999.25*x_('Belgrade',_'Berlin') + 1372.59*x_('Belgrade',_'Brussels') + 447.34*x_('Belgrade',_'Bucharest') + 316.41*x_('Belgrade',_'Budapest') + 1327.24*x_('Belgrade',_'Copenhagen') + 2145.39*x_('Belgrade',_'Dublin') + 1229.93*x_('Belgrade',_'Hamburg') + 809.48*x_('Belgrade',_'Istanbul') + 1497.61*x_('Berlin',_'Barcelona') + 999.25*x_('Berlin',_'Belgrade') + 651.62*x_('Berlin',_'Brussels') + 1293.4*x_('Berlin',_'Bucharest') + 689.06*x_('Berlin',_'Budapest') + 354.03*x_('Berlin',_'Copenhagen') + 1315.16*x_('Berlin',_'Dublin') + 254.51*x_('Berlin',_'Hamburg') + 1735.01*x_('Berlin',_'Istanbul') + 1062.89*x_('Brussels',_'Barcelona') + 1372.59*x_('Brussels',_'Belgrade') + 651.62*x_('Brussels',_'Berlin') + 1769.69*x_('Brussels',_'Bucharest') + 1131.52*x_('Brussels',_'Budapest') + 766.67*x_('Brussels',_'Copenhagen') + 773.2*x_('Brussels',_'Dublin') + 489.76*x_('Brussels',_'Hamburg') + 2178.85*x_('Brussels',_'Istanbul') + 1968.42*x_('Bucharest',_'Barcelona') + 447.34*x_('Bucharest',_'Belgrade') + 1293.4*x_('Bucharest',_'Berlin') + 1769.69*x_('Bucharest',_'Brussels') + 639.77*x_('Bucharest',_'Budapest') + 1571.54*x_('Bucharest',_'Copenhagen') + 2534.72*x_('Bucharest',_'Dublin') + 1544.17*x_('Bucharest',_'Hamburg') + 445.62*x_('Bucharest',_'Istanbul') + 1498.79*x_('Budapest',_'Barcelona') + 316.41*x_('Budapest',_'Belgrade') + 689.06*x_('Budapest',_'Berlin') + 1131.52*x_('Budapest',_'Brussels') + 639.77*x_('Budapest',_'Bucharest') + 1011.31*x_('Budapest',_'Copenhagen') + 1894.95*x_('Budapest',_'Dublin') + 927.92*x_('Budapest',_'Hamburg') + 1064.76*x_('Budapest',_'Istanbul') + 1757.54*x_('Copenhagen',_'Barcelona') + 1327.24*x_('Copenhagen',_'Belgrade') + 354.03*x_('Copenhagen',_'Berlin') + 766.67*x_('Copenhagen',_'Brussels') + 1571.54*x_('Copenhagen',_'Bucharest') + 1011.31*x_('Copenhagen',_'Budapest') + 1238.38*x_('Copenhagen',_'Dublin') + 287.97*x_('Copenhagen',_'Hamburg') + 2017.17*x_('Copenhagen',_'Istanbul') + 1469.29*x_('Dublin',_'Barcelona') + 2145.39*x_('Dublin',_'Belgrade') + 1315.16*x_('Dublin',_'Berlin') + 773.2*x_('Dublin',_'Brussels') + 2534.72*x_('Dublin',_'Bucharest') + 1894.95*x_('Dublin',_'Budapest') + 1238.38*x_('Dublin',_'Copenhagen') + 1073.36*x_('Dublin',_'Hamburg') + 2950.11*x_('Dublin',_'Istanbul') + 1471.78*x_('Hamburg',_'Barcelona') + 1229.93*x_('Hamburg',_'Belgrade') + 254.51*x_('Hamburg',_'Berlin') + 489.76*x_('Hamburg',_'Brussels') + 1544.17*x_('Hamburg',_'Bucharest') + 927.92*x_('Hamburg',_'Budapest') + 287.97*x_('Hamburg',_'Copenhagen') + 1073.36*x_('Hamburg',_'Dublin') + 1983.75*x_('Hamburg',_'Istanbul') + 2230.42*x_('Istanbul',_'Barcelona') + 809.48*x_('Istanbul',_'Belgrade') + 1735.01*x_('Istanbul',_'Berlin') + 2178.85*x_('Istanbul',_'Brussels') + 445.62*x_('Istanbul',_'Bucharest') + 1064.76*x_('Istanbul',_'Budapest') + 2017.17*x_('Istanbul',_'Copenhagen') + 2950.11*x_('Istanbul',_'Dublin') + 1983.75*x_('Istanbul',_'Hamburg') + 0.0
# SUBJECT TO
# _C1: x_('Belgrade',_'Barcelona') + x_('Berlin',_'Barcelona')
#  + x_('Brussels',_'Barcelona') + x_('Bucharest',_'Barcelona')
#  + x_('Budapest',_'Barcelona') + x_('Copenhagen',_'Barcelona')
#  + x_('Dublin',_'Barcelona') + x_('Hamburg',_'Barcelona')
#  + x_('Istanbul',_'Barcelona') = 1
#
# _C2: x_('Barcelona',_'Belgrade') + x_('Barcelona',_'Berlin')
#  + x_('Barcelona',_'Brussels') + x_('Barcelona',_'Bucharest')
#  + x_('Barcelona',_'Budapest') + x_('Barcelona',_'Copenhagen')
#  + x_('Barcelona',_'Dublin') + x_('Barcelona',_'Hamburg')
#  + x_('Barcelona',_'Istanbul') = 1
#
# _C3: x_('Barcelona',_'Belgrade') + x_('Berlin',_'Belgrade')
#  + x_('Brussels',_'Belgrade') + x_('Bucharest',_'Belgrade')
#  + x_('Budapest',_'Belgrade') + x_('Copenhagen',_'Belgrade')
#  + x_('Dublin',_'Belgrade') + x_('Hamburg',_'Belgrade')
#  + x_('Istanbul',_'Belgrade') = 1
#
# _C4: x_('Belgrade',_'Barcelona') + x_('Belgrade',_'Berlin')
#  + x_('Belgrade',_'Brussels') + x_('Belgrade',_'Bucharest')
#  + x_('Belgrade',_'Budapest') + x_('Belgrade',_'Copenhagen')
#  + x_('Belgrade',_'Dublin') + x_('Belgrade',_'Hamburg')
#  + x_('Belgrade',_'Istanbul') = 1
#
# _C5: x_('Barcelona',_'Berlin') + x_('Belgrade',_'Berlin')
#  + x_('Brussels',_'Berlin') + x_('Bucharest',_'Berlin')
#  + x_('Budapest',_'Berlin') + x_('Copenhagen',_'Berlin')
#  + x_('Dublin',_'Berlin') + x_('Hamburg',_'Berlin') + x_('Istanbul',_'Berlin')
#  = 3
#
# _C6: x_('Berlin',_'Barcelona') + x_('Berlin',_'Belgrade')
#  + x_('Berlin',_'Brussels') + x_('Berlin',_'Bucharest')
#  + x_('Berlin',_'Budapest') + x_('Berlin',_'Copenhagen')
#  + x_('Berlin',_'Dublin') + x_('Berlin',_'Hamburg') + x_('Berlin',_'Istanbul')
#  = 3
#
# _C7: x_('Barcelona',_'Brussels') + x_('Belgrade',_'Brussels')
#  + x_('Berlin',_'Brussels') + x_('Bucharest',_'Brussels')
#  + x_('Budapest',_'Brussels') + x_('Copenhagen',_'Brussels')
#  + x_('Dublin',_'Brussels') + x_('Hamburg',_'Brussels')
#  + x_('Istanbul',_'Brussels') = 1
#
# _C8: x_('Brussels',_'Barcelona') + x_('Brussels',_'Belgrade')
#  + x_('Brussels',_'Berlin') + x_('Brussels',_'Bucharest')
#  + x_('Brussels',_'Budapest') + x_('Brussels',_'Copenhagen')
#  + x_('Brussels',_'Dublin') + x_('Brussels',_'Hamburg')
#  + x_('Brussels',_'Istanbul') = 1
#
# _C9: x_('Barcelona',_'Bucharest') + x_('Belgrade',_'Bucharest')
#  + x_('Berlin',_'Bucharest') + x_('Brussels',_'Bucharest')
#  + x_('Budapest',_'Bucharest') + x_('Copenhagen',_'Bucharest')
#  + x_('Dublin',_'Bucharest') + x_('Hamburg',_'Bucharest')
#  + x_('Istanbul',_'Bucharest') = 1
#
# _C10: x_('Bucharest',_'Barcelona') + x_('Bucharest',_'Belgrade')
#  + x_('Bucharest',_'Berlin') + x_('Bucharest',_'Brussels')
#  + x_('Bucharest',_'Budapest') + x_('Bucharest',_'Copenhagen')
#  + x_('Bucharest',_'Dublin') + x_('Bucharest',_'Hamburg')
#  + x_('Bucharest',_'Istanbul') = 1
#
# _C11: x_('Barcelona',_'Budapest') + x_('Belgrade',_'Budapest')
#  + x_('Berlin',_'Budapest') + x_('Brussels',_'Budapest')
#  + x_('Bucharest',_'Budapest') + x_('Copenhagen',_'Budapest')
#  + x_('Dublin',_'Budapest') + x_('Hamburg',_'Budapest')
#  + x_('Istanbul',_'Budapest') = 1
#
# _C12: x_('Budapest',_'Barcelona') + x_('Budapest',_'Belgrade')
#  + x_('Budapest',_'Berlin') + x_('Budapest',_'Brussels')
#  + x_('Budapest',_'Bucharest') + x_('Budapest',_'Copenhagen')
#  + x_('Budapest',_'Dublin') + x_('Budapest',_'Hamburg')
#  + x_('Budapest',_'Istanbul') = 1
#
# _C13: x_('Barcelona',_'Copenhagen') + x_('Belgrade',_'Copenhagen')
#  + x_('Berlin',_'Copenhagen') + x_('Brussels',_'Copenhagen')
#  + x_('Bucharest',_'Copenhagen') + x_('Budapest',_'Copenhagen')
#  + x_('Dublin',_'Copenhagen') + x_('Hamburg',_'Copenhagen')
#  + x_('Istanbul',_'Copenhagen') = 1
#
# _C14: x_('Copenhagen',_'Barcelona') + x_('Copenhagen',_'Belgrade')
#  + x_('Copenhagen',_'Berlin') + x_('Copenhagen',_'Brussels')
#  + x_('Copenhagen',_'Bucharest') + x_('Copenhagen',_'Budapest')
#  + x_('Copenhagen',_'Dublin') + x_('Copenhagen',_'Hamburg')
#  + x_('Copenhagen',_'Istanbul') = 1
#
# _C15: x_('Barcelona',_'Dublin') + x_('Belgrade',_'Dublin')
#  + x_('Berlin',_'Dublin') + x_('Brussels',_'Dublin')
#  + x_('Bucharest',_'Dublin') + x_('Budapest',_'Dublin')
#  + x_('Copenhagen',_'Dublin') + x_('Hamburg',_'Dublin')
#  + x_('Istanbul',_'Dublin') = 1
#
# _C16: x_('Dublin',_'Barcelona') + x_('Dublin',_'Belgrade')
#  + x_('Dublin',_'Berlin') + x_('Dublin',_'Brussels')
#  + x_('Dublin',_'Bucharest') + x_('Dublin',_'Budapest')
#  + x_('Dublin',_'Copenhagen') + x_('Dublin',_'Hamburg')
#  + x_('Dublin',_'Istanbul') = 1
#
# _C17: x_('Barcelona',_'Hamburg') + x_('Belgrade',_'Hamburg')
#  + x_('Berlin',_'Hamburg') + x_('Brussels',_'Hamburg')
#  + x_('Bucharest',_'Hamburg') + x_('Budapest',_'Hamburg')
#  + x_('Copenhagen',_'Hamburg') + x_('Dublin',_'Hamburg')
#  + x_('Istanbul',_'Hamburg') = 1
#
# _C18: x_('Hamburg',_'Barcelona') + x_('Hamburg',_'Belgrade')
#  + x_('Hamburg',_'Berlin') + x_('Hamburg',_'Brussels')
#  + x_('Hamburg',_'Bucharest') + x_('Hamburg',_'Budapest')
#  + x_('Hamburg',_'Copenhagen') + x_('Hamburg',_'Dublin')
#  + x_('Hamburg',_'Istanbul') = 1
#
# _C19: x_('Barcelona',_'Istanbul') + x_('Belgrade',_'Istanbul')
#  + x_('Berlin',_'Istanbul') + x_('Brussels',_'Istanbul')
#  + x_('Bucharest',_'Istanbul') + x_('Budapest',_'Istanbul')
#  + x_('Copenhagen',_'Istanbul') + x_('Dublin',_'Istanbul')
#  + x_('Hamburg',_'Istanbul') = 1
#
# _C20: x_('Istanbul',_'Barcelona') + x_('Istanbul',_'Belgrade')
#  + x_('Istanbul',_'Berlin') + x_('Istanbul',_'Brussels')
#  + x_('Istanbul',_'Bucharest') + x_('Istanbul',_'Budapest')
#  + x_('Istanbul',_'Copenhagen') + x_('Istanbul',_'Dublin')
#  + x_('Istanbul',_'Hamburg') = 1
#
# _C21: u_Barcelona - u_Belgrade + 3.33333333333 x_('Barcelona',_'Belgrade')
#  <= 2.33333333333
#
# _C22: u_Barcelona - u_Brussels + 3.33333333333 x_('Barcelona',_'Brussels')
#  <= 2.33333333333
#
# _C23: u_Barcelona - u_Bucharest + 3.33333333333 x_('Barcelona',_'Bucharest')
#  <= 2.33333333333
#
# _C24: u_Barcelona - u_Budapest + 3.33333333333 x_('Barcelona',_'Budapest')
#  <= 2.33333333333
#
# _C25: u_Barcelona - u_Copenhagen + 3.33333333333 x_('Barcelona',_'Copenhagen')
#  <= 2.33333333333
#
# _C26: u_Barcelona - u_Dublin + 3.33333333333 x_('Barcelona',_'Dublin')
#  <= 2.33333333333
#
# _C27: u_Barcelona - u_Hamburg + 3.33333333333 x_('Barcelona',_'Hamburg')
#  <= 2.33333333333
#
# _C28: u_Barcelona - u_Istanbul + 3.33333333333 x_('Barcelona',_'Istanbul')
#  <= 2.33333333333
#
# _C29: - u_Barcelona + u_Belgrade + 3.33333333333 x_('Belgrade',_'Barcelona')
#  <= 2.33333333333
#
# _C30: u_Belgrade - u_Brussels + 3.33333333333 x_('Belgrade',_'Brussels')
#  <= 2.33333333333
#
# _C31: u_Belgrade - u_Bucharest + 3.33333333333 x_('Belgrade',_'Bucharest')
#  <= 2.33333333333
#
# _C32: u_Belgrade - u_Budapest + 3.33333333333 x_('Belgrade',_'Budapest')
#  <= 2.33333333333
#
# _C33: u_Belgrade - u_Copenhagen + 3.33333333333 x_('Belgrade',_'Copenhagen')
#  <= 2.33333333333
#
# _C34: u_Belgrade - u_Dublin + 3.33333333333 x_('Belgrade',_'Dublin')
#  <= 2.33333333333
#
# _C35: u_Belgrade - u_Hamburg + 3.33333333333 x_('Belgrade',_'Hamburg')
#  <= 2.33333333333
#
# _C36: u_Belgrade - u_Istanbul + 3.33333333333 x_('Belgrade',_'Istanbul')
#  <= 2.33333333333
#
# _C37: - u_Barcelona + u_Brussels + 3.33333333333 x_('Brussels',_'Barcelona')
#  <= 2.33333333333
#
# _C38: - u_Belgrade + u_Brussels + 3.33333333333 x_('Brussels',_'Belgrade')
#  <= 2.33333333333
#
# _C39: u_Brussels - u_Bucharest + 3.33333333333 x_('Brussels',_'Bucharest')
#  <= 2.33333333333
#
# _C40: u_Brussels - u_Budapest + 3.33333333333 x_('Brussels',_'Budapest')
#  <= 2.33333333333
#
# _C41: u_Brussels - u_Copenhagen + 3.33333333333 x_('Brussels',_'Copenhagen')
#  <= 2.33333333333
#
# _C42: u_Brussels - u_Dublin + 3.33333333333 x_('Brussels',_'Dublin')
#  <= 2.33333333333
#
# _C43: u_Brussels - u_Hamburg + 3.33333333333 x_('Brussels',_'Hamburg')
#  <= 2.33333333333
#
# _C44: u_Brussels - u_Istanbul + 3.33333333333 x_('Brussels',_'Istanbul')
#  <= 2.33333333333
#
# _C45: - u_Barcelona + u_Bucharest + 3.33333333333 x_('Bucharest',_'Barcelona')
#  <= 2.33333333333
#
# _C46: - u_Belgrade + u_Bucharest + 3.33333333333 x_('Bucharest',_'Belgrade')
#  <= 2.33333333333
#
# _C47: - u_Brussels + u_Bucharest + 3.33333333333 x_('Bucharest',_'Brussels')
#  <= 2.33333333333
#
# _C48: u_Bucharest - u_Budapest + 3.33333333333 x_('Bucharest',_'Budapest')
#  <= 2.33333333333
#
# _C49: u_Bucharest - u_Copenhagen + 3.33333333333 x_('Bucharest',_'Copenhagen')
#  <= 2.33333333333
#
# _C50: u_Bucharest - u_Dublin + 3.33333333333 x_('Bucharest',_'Dublin')
#  <= 2.33333333333
#
# _C51: u_Bucharest - u_Hamburg + 3.33333333333 x_('Bucharest',_'Hamburg')
#  <= 2.33333333333
#
# _C52: u_Bucharest - u_Istanbul + 3.33333333333 x_('Bucharest',_'Istanbul')
#  <= 2.33333333333
#
# _C53: - u_Barcelona + u_Budapest + 3.33333333333 x_('Budapest',_'Barcelona')
#  <= 2.33333333333
#
# _C54: - u_Belgrade + u_Budapest + 3.33333333333 x_('Budapest',_'Belgrade')
#  <= 2.33333333333
#
# _C55: - u_Brussels + u_Budapest + 3.33333333333 x_('Budapest',_'Brussels')
#  <= 2.33333333333
#
# _C56: - u_Bucharest + u_Budapest + 3.33333333333 x_('Budapest',_'Bucharest')
#  <= 2.33333333333
#
# _C57: u_Budapest - u_Copenhagen + 3.33333333333 x_('Budapest',_'Copenhagen')
#  <= 2.33333333333
#
# _C58: u_Budapest - u_Dublin + 3.33333333333 x_('Budapest',_'Dublin')
#  <= 2.33333333333
#
# _C59: u_Budapest - u_Hamburg + 3.33333333333 x_('Budapest',_'Hamburg')
#  <= 2.33333333333
#
# _C60: u_Budapest - u_Istanbul + 3.33333333333 x_('Budapest',_'Istanbul')
#  <= 2.33333333333
#
# _C61: - u_Barcelona + u_Copenhagen
#  + 3.33333333333 x_('Copenhagen',_'Barcelona') <= 2.33333333333
#
# _C62: - u_Belgrade + u_Copenhagen + 3.33333333333 x_('Copenhagen',_'Belgrade')
#  <= 2.33333333333
#
# _C63: - u_Brussels + u_Copenhagen + 3.33333333333 x_('Copenhagen',_'Brussels')
#  <= 2.33333333333
#
# _C64: - u_Bucharest + u_Copenhagen
#  + 3.33333333333 x_('Copenhagen',_'Bucharest') <= 2.33333333333
#
# _C65: - u_Budapest + u_Copenhagen + 3.33333333333 x_('Copenhagen',_'Budapest')
#  <= 2.33333333333
#
# _C66: u_Copenhagen - u_Dublin + 3.33333333333 x_('Copenhagen',_'Dublin')
#  <= 2.33333333333
#
# _C67: u_Copenhagen - u_Hamburg + 3.33333333333 x_('Copenhagen',_'Hamburg')
#  <= 2.33333333333
#
# _C68: u_Copenhagen - u_Istanbul + 3.33333333333 x_('Copenhagen',_'Istanbul')
#  <= 2.33333333333
#
# _C69: - u_Barcelona + u_Dublin + 3.33333333333 x_('Dublin',_'Barcelona')
#  <= 2.33333333333
#
# _C70: - u_Belgrade + u_Dublin + 3.33333333333 x_('Dublin',_'Belgrade')
#  <= 2.33333333333
#
# _C71: - u_Brussels + u_Dublin + 3.33333333333 x_('Dublin',_'Brussels')
#  <= 2.33333333333
#
# _C72: - u_Bucharest + u_Dublin + 3.33333333333 x_('Dublin',_'Bucharest')
#  <= 2.33333333333
#
# _C73: - u_Budapest + u_Dublin + 3.33333333333 x_('Dublin',_'Budapest')
#  <= 2.33333333333
#
# _C74: - u_Copenhagen + u_Dublin + 3.33333333333 x_('Dublin',_'Copenhagen')
#  <= 2.33333333333
#
# _C75: u_Dublin - u_Hamburg + 3.33333333333 x_('Dublin',_'Hamburg')
#  <= 2.33333333333
#
# _C76: u_Dublin - u_Istanbul + 3.33333333333 x_('Dublin',_'Istanbul')
#  <= 2.33333333333
#
# _C77: - u_Barcelona + u_Hamburg + 3.33333333333 x_('Hamburg',_'Barcelona')
#  <= 2.33333333333
#
# _C78: - u_Belgrade + u_Hamburg + 3.33333333333 x_('Hamburg',_'Belgrade')
#  <= 2.33333333333
#
# _C79: - u_Brussels + u_Hamburg + 3.33333333333 x_('Hamburg',_'Brussels')
#  <= 2.33333333333
#
# _C80: - u_Bucharest + u_Hamburg + 3.33333333333 x_('Hamburg',_'Bucharest')
#  <= 2.33333333333
#
# _C81: - u_Budapest + u_Hamburg + 3.33333333333 x_('Hamburg',_'Budapest')
#  <= 2.33333333333
#
# _C82: - u_Copenhagen + u_Hamburg + 3.33333333333 x_('Hamburg',_'Copenhagen')
#  <= 2.33333333333
#
# _C83: - u_Dublin + u_Hamburg + 3.33333333333 x_('Hamburg',_'Dublin')
#  <= 2.33333333333
#
# _C84: u_Hamburg - u_Istanbul + 3.33333333333 x_('Hamburg',_'Istanbul')
#  <= 2.33333333333
#
# _C85: - u_Barcelona + u_Istanbul + 3.33333333333 x_('Istanbul',_'Barcelona')
#  <= 2.33333333333
#
# _C86: - u_Belgrade + u_Istanbul + 3.33333333333 x_('Istanbul',_'Belgrade')
#  <= 2.33333333333
#
# _C87: - u_Brussels + u_Istanbul + 3.33333333333 x_('Istanbul',_'Brussels')
#  <= 2.33333333333
#
# _C88: - u_Bucharest + u_Istanbul + 3.33333333333 x_('Istanbul',_'Bucharest')
#  <= 2.33333333333
#
# _C89: - u_Budapest + u_Istanbul + 3.33333333333 x_('Istanbul',_'Budapest')
#  <= 2.33333333333
#
# _C90: - u_Copenhagen + u_Istanbul + 3.33333333333 x_('Istanbul',_'Copenhagen')
#  <= 2.33333333333
#
# _C91: - u_Dublin + u_Istanbul + 3.33333333333 x_('Istanbul',_'Dublin')
#  <= 2.33333333333
#
# _C92: - u_Hamburg + u_Istanbul + 3.33333333333 x_('Istanbul',_'Hamburg')
#  <= 2.33333333333
#
# VARIABLES
# 0 <= u_Barcelona <= 9 Integer
# 0 <= u_Belgrade <= 9 Integer
# 0 <= u_Brussels <= 9 Integer
# 0 <= u_Bucharest <= 9 Integer
# 0 <= u_Budapest <= 9 Integer
# 0 <= u_Copenhagen <= 9 Integer
# 0 <= u_Dublin <= 9 Integer
# 0 <= u_Hamburg <= 9 Integer
# 0 <= u_Istanbul <= 9 Integer
# 0 <= x_('Barcelona',_'Belgrade') <= 1 Integer
# 0 <= x_('Barcelona',_'Berlin') <= 1 Integer
# 0 <= x_('Barcelona',_'Brussels') <= 1 Integer
# 0 <= x_('Barcelona',_'Bucharest') <= 1 Integer
# 0 <= x_('Barcelona',_'Budapest') <= 1 Integer
# 0 <= x_('Barcelona',_'Copenhagen') <= 1 Integer
# 0 <= x_('Barcelona',_'Dublin') <= 1 Integer
# 0 <= x_('Barcelona',_'Hamburg') <= 1 Integer
# 0 <= x_('Barcelona',_'Istanbul') <= 1 Integer
# 0 <= x_('Belgrade',_'Barcelona') <= 1 Integer
# 0 <= x_('Belgrade',_'Berlin') <= 1 Integer
# 0 <= x_('Belgrade',_'Brussels') <= 1 Integer
# 0 <= x_('Belgrade',_'Bucharest') <= 1 Integer
# 0 <= x_('Belgrade',_'Budapest') <= 1 Integer
# 0 <= x_('Belgrade',_'Copenhagen') <= 1 Integer
# 0 <= x_('Belgrade',_'Dublin') <= 1 Integer
# 0 <= x_('Belgrade',_'Hamburg') <= 1 Integer
# 0 <= x_('Belgrade',_'Istanbul') <= 1 Integer
# 0 <= x_('Berlin',_'Barcelona') <= 1 Integer
# 0 <= x_('Berlin',_'Belgrade') <= 1 Integer
# 0 <= x_('Berlin',_'Brussels') <= 1 Integer
# 0 <= x_('Berlin',_'Bucharest') <= 1 Integer
# 0 <= x_('Berlin',_'Budapest') <= 1 Integer
# 0 <= x_('Berlin',_'Copenhagen') <= 1 Integer
# 0 <= x_('Berlin',_'Dublin') <= 1 Integer
# 0 <= x_('Berlin',_'Hamburg') <= 1 Integer
# 0 <= x_('Berlin',_'Istanbul') <= 1 Integer
# 0 <= x_('Brussels',_'Barcelona') <= 1 Integer
# 0 <= x_('Brussels',_'Belgrade') <= 1 Integer
# 0 <= x_('Brussels',_'Berlin') <= 1 Integer
# 0 <= x_('Brussels',_'Bucharest') <= 1 Integer
# 0 <= x_('Brussels',_'Budapest') <= 1 Integer
# 0 <= x_('Brussels',_'Copenhagen') <= 1 Integer
# 0 <= x_('Brussels',_'Dublin') <= 1 Integer
# 0 <= x_('Brussels',_'Hamburg') <= 1 Integer
# 0 <= x_('Brussels',_'Istanbul') <= 1 Integer
# 0 <= x_('Bucharest',_'Barcelona') <= 1 Integer
# 0 <= x_('Bucharest',_'Belgrade') <= 1 Integer
# 0 <= x_('Bucharest',_'Berlin') <= 1 Integer
# 0 <= x_('Bucharest',_'Brussels') <= 1 Integer
# 0 <= x_('Bucharest',_'Budapest') <= 1 Integer
# 0 <= x_('Bucharest',_'Copenhagen') <= 1 Integer
# 0 <= x_('Bucharest',_'Dublin') <= 1 Integer
# 0 <= x_('Bucharest',_'Hamburg') <= 1 Integer
# 0 <= x_('Bucharest',_'Istanbul') <= 1 Integer
# 0 <= x_('Budapest',_'Barcelona') <= 1 Integer
# 0 <= x_('Budapest',_'Belgrade') <= 1 Integer
# 0 <= x_('Budapest',_'Berlin') <= 1 Integer
# 0 <= x_('Budapest',_'Brussels') <= 1 Integer
# 0 <= x_('Budapest',_'Bucharest') <= 1 Integer
# 0 <= x_('Budapest',_'Copenhagen') <= 1 Integer
# 0 <= x_('Budapest',_'Dublin') <= 1 Integer
# 0 <= x_('Budapest',_'Hamburg') <= 1 Integer
# 0 <= x_('Budapest',_'Istanbul') <= 1 Integer
# 0 <= x_('Copenhagen',_'Barcelona') <= 1 Integer
# 0 <= x_('Copenhagen',_'Belgrade') <= 1 Integer
# 0 <= x_('Copenhagen',_'Berlin') <= 1 Integer
# 0 <= x_('Copenhagen',_'Brussels') <= 1 Integer
# 0 <= x_('Copenhagen',_'Bucharest') <= 1 Integer
# 0 <= x_('Copenhagen',_'Budapest') <= 1 Integer
# 0 <= x_('Copenhagen',_'Dublin') <= 1 Integer
# 0 <= x_('Copenhagen',_'Hamburg') <= 1 Integer
# 0 <= x_('Copenhagen',_'Istanbul') <= 1 Integer
# 0 <= x_('Dublin',_'Barcelona') <= 1 Integer
# 0 <= x_('Dublin',_'Belgrade') <= 1 Integer
# 0 <= x_('Dublin',_'Berlin') <= 1 Integer
# 0 <= x_('Dublin',_'Brussels') <= 1 Integer
# 0 <= x_('Dublin',_'Bucharest') <= 1 Integer
# 0 <= x_('Dublin',_'Budapest') <= 1 Integer
# 0 <= x_('Dublin',_'Copenhagen') <= 1 Integer
# 0 <= x_('Dublin',_'Hamburg') <= 1 Integer
# 0 <= x_('Dublin',_'Istanbul') <= 1 Integer
# 0 <= x_('Hamburg',_'Barcelona') <= 1 Integer
# 0 <= x_('Hamburg',_'Belgrade') <= 1 Integer
# 0 <= x_('Hamburg',_'Berlin') <= 1 Integer
# 0 <= x_('Hamburg',_'Brussels') <= 1 Integer
# 0 <= x_('Hamburg',_'Bucharest') <= 1 Integer
# 0 <= x_('Hamburg',_'Budapest') <= 1 Integer
# 0 <= x_('Hamburg',_'Copenhagen') <= 1 Integer
# 0 <= x_('Hamburg',_'Dublin') <= 1 Integer
# 0 <= x_('Hamburg',_'Istanbul') <= 1 Integer
# 0 <= x_('Istanbul',_'Barcelona') <= 1 Integer
# 0 <= x_('Istanbul',_'Belgrade') <= 1 Integer
# 0 <= x_('Istanbul',_'Berlin') <= 1 Integer
# 0 <= x_('Istanbul',_'Brussels') <= 1 Integer
# 0 <= x_('Istanbul',_'Bucharest') <= 1 Integer
# 0 <= x_('Istanbul',_'Budapest') <= 1 Integer
# 0 <= x_('Istanbul',_'Copenhagen') <= 1 Integer
# 0 <= x_('Istanbul',_'Dublin') <= 1 Integer
# 0 <= x_('Istanbul',_'Hamburg') <= 1 Integer

# %% [markdown]
# Solve it!

# %%
# %time prob.solve()
#prob.solve(GLPK_CMD(options=['--simplex']))
print(LpStatus[prob.status])
# Out:
# Wall time: 2.13 s
# Optimal

# %%
non_zero_edges = [ e for e in x if value(x[e]) != 0 ]

def get_next_site(parent):
    '''helper function to get the next edge'''
    edges = [e for e in non_zero_edges if e[0]==parent]
    for e in edges:
        non_zero_edges.remove(e)
    return edges

# %%
tours = get_next_site('Berlin')
tours = [ [e] for e in tours ]

for t in tours:
    while t[-1][1] !='Berlin':
        t.append(get_next_site(t[-1][1])[-1])

# %% [markdown]
# The optimal route:

# %%
for t in tours:
    print(' -> '.join([ a for a,b in t]+['Berlin']))
# Out:
# Berlin -> Barcelona -> Dublin -> Brussels -> Berlin
# Berlin -> Bucharest -> Istanbul -> Belgrade -> Berlin
# Berlin -> Budapest -> Copenhagen -> Hamburg -> Berlin

# %% [markdown]
# Calculate total time:

# %%
totalTime = 0;
for t in tours:
    time = 0
    for i in range(0, len(t)):
        time += flighttime.loc[t[i][0], t[i][1]]
#         print(flighttime.loc[t[i][0], t[i][1]])
#     print(time)
    if time > totalTime:
        totalTime = time
print(totalTime)
# Out:
# 1341

# %%
#draw the tours
colors = [np.random.rand(3) for i in range(len(tours))]
for t,c in zip(tours,colors):
    for a,b in t:
        p1,p2 = positions[a], positions[b]
        plt.plot([p1[0],p2[0]],[p1[1],p2[1]], color=c)

#draw the map again
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.title('%d '%K + 'people' if K > 1 else 'person')
plt.xlabel('latitude')
plt.ylabel('longitude')
# plt.gca().axis('off')
plt.show()

# %%
print('Longest time spent:', totalTime, '(min)')
print('Total distance:', value(prob.objective), '(km)')
# Out:
# Longest time spent: 1341 (min)
# Total distance: 10182.319999999998 (km)
