# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\tlhqu\anaconda3\lib\site-packages (2.4)
# Requirement already satisfied: amply>=0.1.2 in c:\users\tlhqu\anaconda3\lib\site-packages (from pulp) (0.1.4)
# Requirement already satisfied: docutils>=0.3 in c:\users\tlhqu\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (0.16)
# Requirement already satisfied: pyparsing in c:\users\tlhqu\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (2.4.7)

# %%
from pulp import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
#a handful of sites
sites = ['Barcelona','Belgrade','Berlin','Brussels','Bucharest','Budapest','Copenhagen','Dublin','Hamburg','Istanbul','Kiev','London','Madrid','Milan','Moscow','Munich','Paris','Prague','Rome','Saint Petersburg','Sofia','Stockholm','Vienna','Warsaw']
# sites = ['Barcelona','Belgrade','Berlin','Brussels','Bucharest','Budapest','Copenhagen']
latlng = ['latitude', 'longitude']
position = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\position.csv', index_col="City")
flighttime = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\flight_time.csv', index_col="City")
distance = pd.read_csv('D:\\Quynh\\Routing_optimization\\vehicle-routing-problem-master\\data\\distance.csv', index_col="City")
position.head(5)
print(len(sites))
# Out:
# 24

# %%
#make some positions (so we can plot this)
positions = dict( ( city, (position.loc[city, 'longitude'], position.loc[city, 'latitude']) ) for city in sites)

# %%
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.gca().axis('off');

# %%
# get distanc between cities
distances = dict( ((s1,s2), distance.loc[s1, s2] ) for s1 in positions for s2 in positions if s1!=s2)

# %% [markdown]
# ## The model
#
# With a few modifications, the original traveling salesman problem can support multiple salesman. Instead of making each facility only be visited once, the origin facility will be visited multiple times. If we have two salesman then the origin is visited exactly twice and so on.
#
# For **K** vehicles or sales people:
#
# ### Variables:
#
# $x_{ij}=
# \begin{cases}
# 1: \text{the path goes from city i to j}\\
# 0: \text{otherwise}
# \end{cases}$
#
# ### order dummy variables:
#
# $u_i - u_j + C*x_{ij} \leq C - d_j, C = N/K$
# $\begin{cases}
# u_i: \text{order that site i is visited}\\
# d_j: \text{the cost to visit city j}, 0 \leq u_i \leq C - d_j, \forall i \in V \setminus \{0\}
# \end{cases}$
#
# ### Goal:
#
# $min\sum_{i=0}^{n}\sum_{j\neq{i}, j=0}^{n}{c_{ij}}{x_{ij}}$
# $\begin{cases}
# c_{ij}: \text{distance from city i to city j}\\
# x_{ij}: \text{whether there's a path between i and j}
# \end{cases}$
#
# ### Constraints:
#
# $\sum_{i\in{V}}{x_{ij} = 1}, \forall j \in V \setminus \{0\}$
#
# $\sum_{j\in{V}}{x_{ij} = 1}, \forall i \in V \setminus \{0\}$
#
# $\sum_{i\in{V}}{x_{i0} = K}$
#
# $\sum_{j\in{V}}{x_{0j} = K}$

# %%
K = 4 #the number of sales people

# %%
#create the problme
prob=LpProblem("vehicle", LpMinimize)

# %%
#indicator variable if site i is connected to site j in the tour
x = LpVariable.dicts('x',distances,0,1,LpBinary)
print(len(x))
#dummy vars to eliminate subtours
u = LpVariable.dicts('u', sites, 0, len(sites)-1, LpInteger)
print(u)
# Out:
# 552
# {'Barcelona': u_Barcelona, 'Belgrade': u_Belgrade, 'Berlin': u_Berlin, 'Brussels': u_Brussels, 'Bucharest': u_Bucharest, 'Budapest': u_Budapest, 'Copenhagen': u_Copenhagen, 'Dublin': u_Dublin, 'Hamburg': u_Hamburg, 'Istanbul': u_Istanbul, 'Kiev': u_Kiev, 'London': u_London, 'Madrid': u_Madrid, 'Milan': u_Milan, 'Moscow': u_Moscow, 'Munich': u_Munich, 'Paris': u_Paris, 'Prague': u_Prague, 'Rome': u_Rome, 'Saint Petersburg': u_Saint_Petersburg, 'Sofia': u_Sofia, 'Stockholm': u_Stockholm, 'Vienna': u_Vienna, 'Warsaw': u_Warsaw}

# %%
#the objective
cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
prob+=cost

# %%
#constraints
for k in sites:
    cap = 1 if k != 'Berlin' else K
    #inbound connection
    prob+= lpSum([ x[(i,k)] for i in sites if (i,k) in x]) ==cap
    #outbound connection
    prob+=lpSum([ x[(k,i)] for i in sites if (k,i) in x]) ==cap
    
#subtour elimination
N=len(sites)/K
for i in sites:
    for j in sites:
        if i != j and (i != 'Berlin' and j!= 'Berlin') and (i,j) in x:
            prob += u[i] - u[j] <= (N)*(1-x[(i,j)]) - 1
print(prob)
# Out:
# vehicle:
# MINIMIZE
# 1528.13*x_('Barcelona',_'Belgrade') + 1497.61*x_('Barcelona',_'Berlin') + 1062.89*x_('Barcelona',_'Brussels') + 1968.42*x_('Barcelona',_'Bucharest') + 1498.79*x_('Barcelona',_'Budapest') + 1757.54*x_('Barcelona',_'Copenhagen') + 1469.29*x_('Barcelona',_'Dublin') + 1471.78*x_('Barcelona',_'Hamburg') + 2230.42*x_('Barcelona',_'Istanbul') + 2391.06*x_('Barcelona',_'Kiev') + 1137.67*x_('Barcelona',_'London') + 504.64*x_('Barcelona',_'Madrid') + 725.12*x_('Barcelona',_'Milan') + 3006.93*x_('Barcelona',_'Moscow') + 1054.55*x_('Barcelona',_'Munich') + 831.59*x_('Barcelona',_'Paris') + 1353.9*x_('Barcelona',_'Prague') + 856.69*x_('Barcelona',_'Rome') + 2813.02*x_('Barcelona',_'Saint_Petersburg') + 1745.55*x_('Barcelona',_'Sofia') + 2276.51*x_('Barcelona',_'Stockholm') + 1347.43*x_('Barcelona',_'Vienna') + 1862.33*x_('Barcelona',_'Warsaw') + 1528.13*x_('Belgrade',_'Barcelona') + 999.25*x_('Belgrade',_'Berlin') + 1372.59*x_('Belgrade',_'Brussels') + 447.34*x_('Belgrade',_'Bucharest') + 316.41*x_('Belgrade',_'Budapest') + 1327.24*x_('Belgrade',_'Copenhagen') + 2145.39*x_('Belgrade',_'Dublin') + 1229.93*x_('Belgrade',_'Hamburg') + 809.48*x_('Belgrade',_'Istanbul') + 976.02*x_('Belgrade',_'Kiev') + 1688.97*x_('Belgrade',_'London') + 2026.94*x_('Belgrade',_'Madrid') + 885.32*x_('Belgrade',_'Milan') + 1710.99*x_('Belgrade',_'Moscow') + 773.33*x_('Belgrade',_'Munich') + 1445.7*x_('Belgrade',_'Paris') + 738.1*x_('Belgrade',_'Prague') + 721.55*x_('Belgrade',_'Rome') + 1797.75*x_('Belgrade',_'Saint_Petersburg') + 329.46*x_('Belgrade',_'Sofia') + 1620.96*x_('Belgrade',_'Stockholm') + 489.28*x_('Belgrade',_'Vienna') + 826.66*x_('Belgrade',_'Warsaw') + 1497.61*x_('Berlin',_'Barcelona') + 999.25*x_('Berlin',_'Belgrade') + 651.62*x_('Berlin',_'Brussels') + 1293.4*x_('Berlin',_'Bucharest') + 689.06*x_('Berlin',_'Budapest') + 354.03*x_('Berlin',_'Copenhagen') + 1315.16*x_('Berlin',_'Dublin') + 254.51*x_('Berlin',_'Hamburg') + 1735.01*x_('Berlin',_'Istanbul') + 1204.0*x_('Berlin',_'Kiev') + 929.97*x_('Berlin',_'London') + 1867.69*x_('Berlin',_'Madrid') + 840.72*x_('Berlin',_'Milan') + 1607.99*x_('Berlin',_'Moscow') + 501.97*x_('Berlin',_'Munich') + 876.96*x_('Berlin',_'Paris') + 280.34*x_('Berlin',_'Prague') + 1181.67*x_('Berlin',_'Rome') + 1319.62*x_('Berlin',_'Saint_Petersburg') + 1318.67*x_('Berlin',_'Sofia') + 810.38*x_('Berlin',_'Stockholm') + 523.61*x_('Berlin',_'Vienna') + 516.06*x_('Berlin',_'Warsaw') + 1062.89*x_('Brussels',_'Barcelona') + 1372.59*x_('Brussels',_'Belgrade') + 651.62*x_('Brussels',_'Berlin') + 1769.69*x_('Brussels',_'Bucharest') + 1131.52*x_('Brussels',_'Budapest') + 766.67*x_('Brussels',_'Copenhagen') + 773.2*x_('Brussels',_'Dublin') + 489.76*x_('Brussels',_'Hamburg') + 2178.85*x_('Brussels',_'Istanbul') + 1836.2*x_('Brussels',_'Kiev') + 318.72*x_('Brussels',_'London') + 1314.3*x_('Brussels',_'Madrid') + 696.61*x_('Brussels',_'Milan') + 2253.26*x_('Brussels',_'Moscow') + 601.87*x_('Brussels',_'Munich') + 261.29*x_('Brussels',_'Paris') + 721.08*x_('Brussels',_'Prague') + 1171.34*x_('Brussels',_'Rome') + 1903.66*x_('Brussels',_'Saint_Petersburg') + 1697.83*x_('Brussels',_'Sofia') + 1280.88*x_('Brussels',_'Stockholm') + 914.81*x_('Brussels',_'Vienna') + 1159.85*x_('Brussels',_'Warsaw') + 1968.42*x_('Bucharest',_'Barcelona') + 447.34*x_('Bucharest',_'Belgrade') + 1293.4*x_('Bucharest',_'Berlin') + 1769.69*x_('Bucharest',_'Brussels') + 639.77*x_('Bucharest',_'Budapest') + 1571.54*x_('Bucharest',_'Copenhagen') + 2534.72*x_('Bucharest',_'Dublin') + 1544.17*x_('Bucharest',_'Hamburg') + 445.62*x_('Bucharest',_'Istanbul') + 744.44*x_('Bucharest',_'Kiev') + 2088.42*x_('Bucharest',_'London') + 2469.71*x_('Bucharest',_'Madrid') + 1331.46*x_('Bucharest',_'Milan') + 1497.56*x_('Bucharest',_'Moscow') + 1186.37*x_('Bucharest',_'Munich') + 1869.95*x_('Bucharest',_'Paris') + 1076.82*x_('Bucharest',_'Prague') + 1137.38*x_('Bucharest',_'Rome') + 1740.39*x_('Bucharest',_'Saint_Petersburg') + 296.68*x_('Bucharest',_'Sofia') + 1742.25*x_('Bucharest',_ ...
# SUBJECT TO
# _C1: x_('Belgrade',_'Barcelona') + x_('Berlin',_'Barcelona')
#  + x_('Brussels',_'Barcelona') + x_('Bucharest',_'Barcelona')
#  + x_('Budapest',_'Barcelona') + x_('Copenhagen',_'Barcelona')
#  + x_('Dublin',_'Barcelona') + x_('Hamburg',_'Barcelona')
#  + x_('Istanbul',_'Barcelona') + x_('Kiev',_'Barcelona')
#  + x_('London',_'Barcelona') + x_('Madrid',_'Barcelona')
#  + x_('Milan',_'Barcelona') + x_('Moscow',_'Barcelona')
#  + x_('Munich',_'Barcelona') + x_('Paris',_'Barcelona')
#  + x_('Prague',_'Barcelona') + x_('Rome',_'Barcelona')
#  + x_('Saint_Petersburg',_'Barcelona') + x_('Sofia',_'Barcelona')
#  + x_('Stockholm',_'Barcelona') + x_('Vienna',_'Barcelona')
#  + x_('Warsaw',_'Barcelona') = 1
#
# _C2: x_('Barcelona',_'Belgrade') + x_('Barcelona',_'Berlin')
#  + x_('Barcelona',_'Brussels') + x_('Barcelona',_'Bucharest')
#  + x_('Barcelona',_'Budapest') + x_('Barcelona',_'Copenhagen')
#  + x_('Barcelona',_'Dublin') + x_('Barcelona',_'Hamburg')
#  + x_('Barcelona',_'Istanbul') + x_('Barcelona',_'Kiev')
#  + x_('Barcelona',_'London') + x_('Barcelona',_'Madrid')
#  + x_('Barcelona',_'Milan') + x_('Barcelona',_'Moscow')
#  + x_('Barcelona',_'Munich') + x_('Barcelona',_'Paris')
#  + x_('Barcelona',_'Prague') + x_('Barcelona',_'Rome')
#  + x_('Barcelona',_'Saint_Petersburg') + x_('Barcelona',_'Sofia')
#  + x_('Barcelona',_'Stockholm') + x_('Barcelona',_'Vienna')
#  + x_('Barcelona',_'Warsaw') = 1
#
# _C3: x_('Barcelona',_'Belgrade') + x_('Berlin',_'Belgrade')
#  + x_('Brussels',_'Belgrade') + x_('Bucharest',_'Belgrade')
#  + x_('Budapest',_'Belgrade') + x_('Copenhagen',_'Belgrade')
#  + x_('Dublin',_'Belgrade') + x_('Hamburg',_'Belgrade')
#  + x_('Istanbul',_'Belgrade') + x_('Kiev',_'Belgrade')
#  + x_('London',_'Belgrade') + x_('Madrid',_'Belgrade')
#  + x_('Milan',_'Belgrade') + x_('Moscow',_'Belgrade')
#  + x_('Munich',_'Belgrade') + x_('Paris',_'Belgrade')
#  + x_('Prague',_'Belgrade') + x_('Rome',_'Belgrade')
#  + x_('Saint_Petersburg',_'Belgrade') + x_('Sofia',_'Belgrade')
#  + x_('Stockholm',_'Belgrade') + x_('Vienna',_'Belgrade')
#  + x_('Warsaw',_'Belgrade') = 1
#
# _C4: x_('Belgrade',_'Barcelona') + x_('Belgrade',_'Berlin')
#  + x_('Belgrade',_'Brussels') + x_('Belgrade',_'Bucharest')
#  + x_('Belgrade',_'Budapest') + x_('Belgrade',_'Copenhagen')
#  + x_('Belgrade',_'Dublin') + x_('Belgrade',_'Hamburg')
#  + x_('Belgrade',_'Istanbul') + x_('Belgrade',_'Kiev')
#  + x_('Belgrade',_'London') + x_('Belgrade',_'Madrid')
#  + x_('Belgrade',_'Milan') + x_('Belgrade',_'Moscow')
#  + x_('Belgrade',_'Munich') + x_('Belgrade',_'Paris')
#  + x_('Belgrade',_'Prague') + x_('Belgrade',_'Rome')
#  + x_('Belgrade',_'Saint_Petersburg') + x_('Belgrade',_'Sofia')
#  + x_('Belgrade',_'Stockholm') + x_('Belgrade',_'Vienna')
#  + x_('Belgrade',_'Warsaw') = 1
#
# _C5: x_('Barcelona',_'Berlin') + x_('Belgrade',_'Berlin')
#  + x_('Brussels',_'Berlin') + x_('Bucharest',_'Berlin')
#  + x_('Budapest',_'Berlin') + x_('Copenhagen',_'Berlin')
#  + x_('Dublin',_'Berlin') + x_('Hamburg',_'Berlin') + x_('Istanbul',_'Berlin')
#  + x_('Kiev',_'Berlin') + x_('London',_'Berlin') + x_('Madrid',_'Berlin')
#  + x_('Milan',_'Berlin') + x_('Moscow',_'Berlin') + x_('Munich',_'Berlin')
#  + x_('Paris',_'Berlin') + x_('Prague',_'Berlin') + x_('Rome',_'Berlin')
#  + x_('Saint_Petersburg',_'Berlin') + x_('Sofia',_'Berlin')
#  + x_('Stockholm',_'Berlin') + x_('Vienna',_'Berlin') + x_('Warsaw',_'Berlin')
#  = 4
#
# _C6: x_('Berlin',_'Barcelona') + x_('Berlin',_'Belgrade')
#  + x_('Berlin',_'Brussels') + x_('Berlin',_'Bucharest')
#  + x_('Berlin',_'Budapest') + x_('Berlin',_'Copenhagen')
#  + x_('Berlin',_'Dublin') + x_('Berlin',_'Hamburg') + x_('Berlin',_'Istanbul')
#  + x_('Berlin',_'Kiev') + x_('Berlin',_'London') + x_('Berlin',_'Madrid')
#  + x_('Berlin',_'Milan') + x_('Berlin',_'Moscow') + x_('Berlin',_'Munich')
#  + x_('Berlin',_'Paris') + x_('Berlin',_'Prague') + x_('Berlin',_'Rome')
#  + x_('Berlin',_'Saint_Petersburg') + x_('Berlin',_'Sofia')
#  + x_('Berlin',_'Stockholm') + x_('Berlin',_'Vienna') + x_('Berlin',_'Warsaw')
#  = 4
#
# _C7: x_('Barcelona',_'Brussels') + x_('Belgrade',_'Brussels')
#  + x_('Berlin',_'Brussels') + x_('Bucharest',_'Brussels')
#  + x_('Budapest',_'Brussels') + x_('Copenhagen',_'Brussels')
#  + x_('Dublin',_'Brussels') + x_('Hamburg',_'Brussels')
#  + x_('Istanbul',_'Brussels') + x_('Kiev',_'Brussels')
#  + x_('London',_'Brussels') + x_('Madrid',_'Brussels')
#  + x_('Milan',_'Brussels') + x_('Moscow',_'Brussels')
#  + x_('Munich',_'Brussels') + x_('Paris',_'Brussels')
#  + x_('Prague',_'Brussels') + x_('Rome',_'Brussels')
#  + x_('Saint_Petersburg',_'Brussels') + x_('Sofia',_'Brussels')
#  + x_('Stockholm',_'Brussels') + x_('Vienna',_'Brussels')
#  + x_('Warsaw',_'Brussels') = 1
#
# _C8: x_('Brussels',_'Barcelona') + x_('Brussels',_'Belgrade')
#  + x_('Brussels',_'Berlin') + x_('Brussels',_'Bucharest')
#  + x_('Brussels',_'Budapest') + x_('Brussels',_'Copenhagen')
#  + x_('Brussels',_'Dublin') + x_('Brussels',_'Hamburg')
#  + x_('Brussels',_'Istanbul') + x_('Brussels',_'Kiev')
#  + x_('Brussels',_'London') + x_('Brussels',_'Madrid')
#  + x_('Brussels',_'Milan') + x_('Brussels',_'Moscow')
#  + x_('Brussels',_'Munich') + x_('Brussels',_'Paris')
#  + x_('Brussels',_'Prague') + x_('Brussels',_'Rome')
#  + x_('Brussels',_'Saint_Petersburg') + x_('Brussels',_'Sofia')
#  + x_('Brussels',_'Stockholm') + x_('Brussels',_'Vienna')
#  + x_('Brussels',_'Warsaw') = 1
#
# _C9: x_('Barcelona',_'Bucharest') + x_('Belgrade',_'Bucharest')
#  + x_('Berlin',_'Bucharest') + x_('Brussels',_'Bucharest')
#  + x_('Budapest',_'Bucharest') + x_('Copenhagen',_'Bucharest')
#  + x_('Dublin',_'Bucharest') + x_('Hamburg',_'Bucharest')
#  + x_('Istanbul',_'Bucharest') + x_('Kiev',_'Bucharest')
#  + x_('London',_'Bucharest') + x_('Madrid',_'Bucharest')
#  + x_('Milan',_'Bucharest') + x_('Moscow',_'Bucharest')
#  + x_('Munich',_'Bucharest') + x_('Paris',_'Bucharest')
#  + x_('Prague',_'Bucharest') + x_('Rome',_'Bucharest')
#  + x_('Saint_Petersburg',_'Bucharest') + x_('Sofia',_'Bucharest')
#  + x_('Stockholm',_'Bucharest') + x_('Vienna',_'Bucharest')
#  + x_('Warsaw',_'Bucharest') = 1
#
# _C10: x_('Bucharest',_'Barcelona') + x_('Bucharest',_'Belgrade')
#  + x_('Bucharest',_'Berlin') + x_('Bucharest',_'Brussels')
#  + x_('Bucharest',_'Budapest') + x_('Bucharest',_'Copenhagen')
#  + x_('Bucharest',_'Dublin') + x_('Bucharest',_'Hamburg')
#  + x_('Bucharest',_'Istanbul') + x_('Bucharest',_'Kiev')
#  + x_('Bucharest',_'London') + x_('Bucharest',_'Madrid')
#  + x_('Bucharest',_'Milan') + x_('Bucharest',_'Moscow')
#  + x_('Bucharest',_'Munich') + x_('Bucharest',_'Paris')
#  + x_('Bucharest',_'Prague') + x_('Bucharest',_'Rome')
#  + x_('Bucharest',_'Saint_Petersburg') + x_('Bucharest',_'Sofia')
#  + x_('Bucharest',_'Stockholm') + x_('Bucharest',_'Vienna')
#  + x_('Bucharest',_'Warsaw') = 1
#
# _C11: x_('Barcelona',_'Budapest') + x_('Belgrade',_'Budapest')
#  + x_('Berlin',_'Budapest') + x_('Brussels',_'Budapest')
#  + x_('Bucharest',_'Budapest') + x_('Copenhagen',_'Budapest')
#  + x_('Dublin',_'Budapest') + x_('Hamburg',_'Budapest')
#  + x_('Istanbul',_'Budapest') + x_('Kiev',_'Budapest')
#  + x_('London',_'Budapest') + x_('Madrid',_'Budapest')
#  + x_('Milan',_'Budapest') + x_('Moscow',_'Budapest')
#  + x_('Munich',_'Budapest') + x_('Paris',_'Budapest')
#  + x_('Prague',_'Budapest') + x_('Rome',_'Budapest')
#  + x_('Saint_Petersburg',_'Budapest') + x_('Sofia',_'Budapest')
#  + x_('Stockholm',_'Budapest') + x_('Vienna',_'Budapest')
#  + x_('Warsaw',_'Budapest') = 1
#
# _C12: x_('Budapest',_'Barcelona') + x_('Budapest',_'Belgrade')
#  + x_('Budapest',_'Berlin') + x_('Budapest',_'Brussels')
#  + x_('Budapest',_'Bucharest') + x_('Budapest',_'Copenhagen')
#  + x_('Budapest',_'Dublin') + x_('Budapest',_'Hamburg')
#  + x_('Budapest',_'Istanbul') + x_('Budapest',_'Kiev')
#  + x_('Budapest',_'London') + x_('Budapest',_'Madrid')
#  + x_('Budapest',_'Milan') + x_('Budapest',_'Moscow')
#  + x_('Budapest',_'Munich') + x_('Budapest',_'Paris')
#  + x_('Budapest',_'Prague') + x_('Budapest',_'Rome')
#  + x_('Budapest',_'Saint_Petersburg') + x_('Budapest',_'Sofia')
#  + x_('Budapest',_'Stockholm') + x_('Budapest',_'Vienna')
#  + x_('Budapest',_'Warsaw') = 1
#
# _C13: x_('Barcelona',_'Copenhagen') + x_('Belgrade',_'Copenhagen')
#  + x_('Berlin',_'Copenhagen') + x_('Brussels',_'Copenhagen')
#  + x_('Bucharest',_'Copenhagen') + x_('Budapest',_'Copenhagen')
#  + x_('Dublin',_'Copenhagen') + x_('Hamburg',_'Copenhagen')
#  + x_('Istanbul',_'Copenhagen') + x_('Kiev',_'Copenhagen')
#  + x_('London',_'Copenhagen') + x_('Madrid',_'Copenhagen')
#  + x_('Milan',_'Copenhagen') + x_('Moscow',_'Copenhagen')
#  + x_('Munich',_'Copenhagen') + x_('Paris',_'Copenhagen')
#  + x_('Prague',_'Copenhagen') + x_('Rome',_'Copenhagen')
#  + x_('Saint_Petersburg',_'Copenhagen') + x_('Sofia',_'Copenhagen')
#  + x_('Stockholm',_'Copenhagen') + x_('Vienna',_'Copenhagen')
#  + x_('Warsaw',_'Copenhagen') = 1
#
# _C14: x_('Copenhagen',_'Barcelona') + x_('Copenhagen',_'Belgrade')
#  + x_('Copenhagen',_'Berlin') + x_('Copenhagen',_'Brussels')
#  + x_('Copenhagen',_'Bucharest') + x_('Copenhagen',_'Budapest')
#  + x_('Copenhagen',_'Dublin') + x_('Copenhagen',_'Hamburg')
#  + x_('Copenhagen',_'Istanbul') + x_('Copenhagen',_'Kiev')
#  + x_('Copenhagen',_'London') + x_('Copenhagen',_'Madrid')
#  + x_('Copenhagen',_'Milan') + x_('Copenhagen',_'Moscow')
#  + x_('Copenhagen',_'Munich') + x_('Copenhagen',_'Paris')
#  + x_('Copenhagen',_'Prague') + x_('Copenhagen',_'Rome')
#  + x_('Copenhagen',_'Saint_Petersburg') + x_('Copenhagen',_'Sofia')
#  + x_('Copenhagen',_'Stockholm') + x_('Copenhagen',_'Vienna')
#  + x_('Copenhagen',_'Warsaw') = 1
#
# _C15: x_('Barcelona',_'Dublin') + x_('Belgrade',_'Dublin')
#  + x_('Berlin',_'Dublin') + x_('Brussels',_'Dublin')
#  + x_('Bucharest',_'Dublin') + x_('Budapest',_'Dublin')
#  + x_('Copenhagen',_'Dublin') + x_('Hamburg',_'Dublin')
#  + x_('Istanbul',_'Dublin') + x_('Kiev',_'Dublin') + x_('London',_'Dublin')
#  + x_('Madrid',_'Dublin') + x_('Milan',_'Dublin') + x_('Moscow',_'Dublin')
#  + x_('Munich',_'Dublin') + x_('Paris',_'Dublin') + x_('Prague',_'Dublin')
#  + x_('Rome',_'Dublin') + x_('Saint_Petersburg',_'Dublin')
#  + x_('Sofia',_'Dublin') + x_('Stockholm',_'Dublin') + x_('Vienna',_'Dublin')
#  + x_('Warsaw',_'Dublin') = 1
#
# _C16: x_('Dublin',_'Barcelona') + x_('Dublin',_'Belgrade')
#  + x_('Dublin',_'Berlin') + x_('Dublin',_'Brussels')
#  + x_('Dublin',_'Bucharest') + x_('Dublin',_'Budapest')
#  + x_('Dublin',_'Copenhagen') + x_('Dublin',_'Hamburg')
#  + x_('Dublin',_'Istanbul') + x_('Dublin',_'Kiev') + x_('Dublin',_'London')
#  + x_('Dublin',_'Madrid') + x_('Dublin',_'Milan') + x_('Dublin',_'Moscow')
#  + x_('Dublin',_'Munich') + x_('Dublin',_'Paris') + x_('Dublin',_'Prague')
#  + x_('Dublin',_'Rome') + x_('Dublin',_'Saint_Petersburg')
#  + x_('Dublin',_'Sofia') + x_('Dublin',_'Stockholm') + x_('Dublin',_'Vienna')
#  + x_('Dublin',_'Warsaw') = 1
#
# _C17: x_('Barcelona',_'Hamburg') + x_('Belgrade',_'Hamburg')
#  + x_('Berlin',_'Hamburg') + x_('Brussels',_'Hamburg')
#  + x_('Bucharest',_'Hamburg') + x_('Budapest',_'Hamburg')
#  + x_('Copenhagen',_'Hamburg') + x_('Dublin',_'Hamburg')
#  + x_('Istanbul',_'Hamburg') + x_('Kiev',_'Hamburg') + x_('London',_'Hamburg')
#  + x_('Madrid',_'Hamburg') + x_('Milan',_'Hamburg') + x_('Moscow',_'Hamburg')
#  + x_('Munich',_'Hamburg') + x_('Paris',_'Hamburg') + x_('Prague',_'Hamburg')
#  + x_('Rome',_'Hamburg') + x_('Saint_Petersburg',_'Hamburg')
#  + x_('Sofia',_'Hamburg') + x_('Stockholm',_'Hamburg')
#  + x_('Vienna',_'Hamburg') + x_('Warsaw',_'Hamburg') = 1
#
# _C18: x_('Hamburg',_'Barcelona') + x_('Hamburg',_'Belgrade')
#  + x_('Hamburg',_'Berlin') + x_('Hamburg',_'Brussels')
#  + x_('Hamburg',_'Bucharest') + x_('Hamburg',_'Budapest')
#  + x_('Hamburg',_'Copenhagen') + x_('Hamburg',_'Dublin')
#  + x_('Hamburg',_'Istanbul') + x_('Hamburg',_'Kiev') + x_('Hamburg',_'London')
#  + x_('Hamburg',_'Madrid') + x_('Hamburg',_'Milan') + x_('Hamburg',_'Moscow')
#  + x_('Hamburg',_'Munich') + x_('Hamburg',_'Paris') + x_('Hamburg',_'Prague')
#  + x_('Hamburg',_'Rome') + x_('Hamburg',_'Saint_Petersburg')
#  + x_('Hamburg',_'Sofia') + x_('Hamburg',_'Stockholm')
#  + x_('Hamburg',_'Vienna') + x_('Hamburg',_'Warsaw') = 1
#
# _C19: x_('Barcelona',_'Istanbul') + x_('Belgrade',_'Istanbul')
#  + x_('Berlin',_'Istanbul') + x_('Brussels',_'Istanbul')
#  + x_('Bucharest',_'Istanbul') + x_('Budapest',_'Istanbul')
#  + x_('Copenhagen',_'Istanbul') + x_('Dublin',_'Istanbul')
#  + x_('Hamburg',_'Istanbul') + x_('Kiev',_'Istanbul')
#  + x_('London',_'Istanbul') + x_('Madrid',_'Istanbul')
#  + x_('Milan',_'Istanbul') + x_('Moscow',_'Istanbul')
#  + x_('Munich',_'Istanbul') + x_('Paris',_'Istanbul')
#  + x_('Prague',_'Istanbul') + x_('Rome',_'Istanbul')
#  + x_('Saint_Petersburg',_'Istanbul') + x_('Sofia',_'Istanbul')
#  + x_('Stockholm',_'Istanbul') + x_('Vienna',_'Istanbul')
#  + x_('Warsaw',_'Istanbul') = 1
#
# _C20: x_('Istanbul',_'Barcelona') + x_('Istanbul',_'Belgrade')
#  + x_('Istanbul',_'Berlin') + x_('Istanbul',_'Brussels')
#  + x_('Istanbul',_'Bucharest') + x_('Istanbul',_'Budapest')
#  + x_('Istanbul',_'Copenhagen') + x_('Istanbul',_'Dublin')
#  + x_('Istanbul',_'Hamburg') + x_('Istanbul',_'Kiev')
#  + x_('Istanbul',_'London') + x_('Istanbul',_'Madrid')
#  + x_('Istanbul',_'Milan') + x_('Istanbul',_'Moscow')
#  + x_('Istanbul',_'Munich') + x_('Istanbul',_'Paris')
#  + x_('Istanbul',_'Prague') + x_('Istanbul',_'Rome')
#  + x_('Istanbul',_'Saint_Petersburg') + x_('Istanbul',_'Sofia')
#  + x_('Istanbul',_'Stockholm') + x_('Istanbul',_'Vienna')
#  + x_('Istanbul',_'Warsaw') = 1
#
# _C21: x_('Barcelona',_'Kiev') + x_('Belgrade',_'Kiev') + x_('Berlin',_'Kiev')
#  + x_('Brussels',_'Kiev') + x_('Bucharest',_'Kiev') + x_('Budapest',_'Kiev')
#  + x_('Copenhagen',_'Kiev') + x_('Dublin',_'Kiev') + x_('Hamburg',_'Kiev')
#  + x_('Istanbul',_'Kiev') + x_('London',_'Kiev') + x_('Madrid',_'Kiev')
#  + x_('Milan',_'Kiev') + x_('Moscow',_'Kiev') + x_('Munich',_'Kiev')
#  + x_('Paris',_'Kiev') + x_('Prague',_'Kiev') + x_('Rome',_'Kiev')
#  + x_('Saint_Petersburg',_'Kiev') + x_('Sofia',_'Kiev')
#  + x_('Stockholm',_'Kiev') + x_('Vienna',_'Kiev') + x_('Warsaw',_'Kiev') = 1
#
# _C22: x_('Kiev',_'Barcelona') + x_('Kiev',_'Belgrade') + x_('Kiev',_'Berlin')
#  + x_('Kiev',_'Brussels') + x_('Kiev',_'Bucharest') + x_('Kiev',_'Budapest')
#  + x_('Kiev',_'Copenhagen') + x_('Kiev',_'Dublin') + x_('Kiev',_'Hamburg')
#  + x_('Kiev',_'Istanbul') + x_('Kiev',_'London') + x_('Kiev',_'Madrid')
#  + x_('Kiev',_'Milan') + x_('Kiev',_'Moscow') + x_('Kiev',_'Munich')
#  + x_('Kiev',_'Paris') + x_('Kiev',_'Prague') + x_('Kiev',_'Rome')
#  + x_('Kiev',_'Saint_Petersburg') + x_('Kiev',_'Sofia')
#  + x_('Kiev',_'Stockholm') + x_('Kiev',_'Vienna') + x_('Kiev',_'Warsaw') = 1
#
# _C23: x_('Barcelona',_'London') + x_('Belgrade',_'London')
#  + x_('Berlin',_'London') + x_('Brussels',_'London')
#  + x_('Bucharest',_'London') + x_('Budapest',_'London')
#  + x_('Copenhagen',_'London') + x_('Dublin',_'London')
#  + x_('Hamburg',_'London') + x_('Istanbul',_'London') + x_('Kiev',_'London')
#  + x_('Madrid',_'London') + x_('Milan',_'London') + x_('Moscow',_'London')
#  + x_('Munich',_'London') + x_('Paris',_'London') + x_('Prague',_'London')
#  + x_('Rome',_'London') + x_('Saint_Petersburg',_'London')
#  + x_('Sofia',_'London') + x_('Stockholm',_'London') + x_('Vienna',_'London')
#  + x_('Warsaw',_'London') = 1
#
# _C24: x_('London',_'Barcelona') + x_('London',_'Belgrade')
#  + x_('London',_'Berlin') + x_('London',_'Brussels')
#  + x_('London',_'Bucharest') + x_('London',_'Budapest')
#  + x_('London',_'Copenhagen') + x_('London',_'Dublin')
#  + x_('London',_'Hamburg') + x_('London',_'Istanbul') + x_('London',_'Kiev')
#  + x_('London',_'Madrid') + x_('London',_'Milan') + x_('London',_'Moscow')
#  + x_('London',_'Munich') + x_('London',_'Paris') + x_('London',_'Prague')
#  + x_('London',_'Rome') + x_('London',_'Saint_Petersburg')
#  + x_('London',_'Sofia') + x_('London',_'Stockholm') + x_('London',_'Vienna')
#  + x_('London',_'Warsaw') = 1
#
# _C25: x_('Barcelona',_'Madrid') + x_('Belgrade',_'Madrid')
#  + x_('Berlin',_'Madrid') + x_('Brussels',_'Madrid')
#  + x_('Bucharest',_'Madrid') + x_('Budapest',_'Madrid')
#  + x_('Copenhagen',_'Madrid') + x_('Dublin',_'Madrid')
#  + x_('Hamburg',_'Madrid') + x_('Istanbul',_'Madrid') + x_('Kiev',_'Madrid')
#  + x_('London',_'Madrid') + x_('Milan',_'Madrid') + x_('Moscow',_'Madrid')
#  + x_('Munich',_'Madrid') + x_('Paris',_'Madrid') + x_('Prague',_'Madrid')
#  + x_('Rome',_'Madrid') + x_('Saint_Petersburg',_'Madrid')
#  + x_('Sofia',_'Madrid') + x_('Stockholm',_'Madrid') + x_('Vienna',_'Madrid')
#  + x_('Warsaw',_'Madrid') = 1
#
# _C26: x_('Madrid',_'Barcelona') + x_('Madrid',_'Belgrade')
#  + x_('Madrid',_'Berlin') + x_('Madrid',_'Brussels')
#  + x_('Madrid',_'Bucharest') + x_('Madrid',_'Budapest')
#  + x_('Madrid',_'Copenhagen') + x_('Madrid',_'Dublin')
#  + x_('Madrid',_'Hamburg') + x_('Madrid',_'Istanbul') + x_('Madrid',_'Kiev')
#  + x_('Madrid',_'London') + x_('Madrid',_'Milan') + x_('Madrid',_'Moscow')
#  + x_('Madrid',_'Munich') + x_('Madrid',_'Paris') + x_('Madrid',_'Prague')
#  + x_('Madrid',_'Rome') + x_('Madrid',_'Saint_Petersburg')
#  + x_('Madrid',_'Sofia') + x_('Madrid',_'Stockholm') + x_('Madrid',_'Vienna')
#  + x_('Madrid',_'Warsaw') = 1
#
# _C27: x_('Barcelona',_'Milan') + x_('Belgrade',_'Milan')
#  + x_('Berlin',_'Milan') + x_('Brussels',_'Milan') + x_('Bucharest',_'Milan')
#  + x_('Budapest',_'Milan') + x_('Copenhagen',_'Milan') + x_('Dublin',_'Milan')
#  + x_('Hamburg',_'Milan') + x_('Istanbul',_'Milan') + x_('Kiev',_'Milan')
#  + x_('London',_'Milan') + x_('Madrid',_'Milan') + x_('Moscow',_'Milan')
#  + x_('Munich',_'Milan') + x_('Paris',_'Milan') + x_('Prague',_'Milan')
#  + x_('Rome',_'Milan') + x_('Saint_Petersburg',_'Milan')
#  + x_('Sofia',_'Milan') + x_('Stockholm',_'Milan') + x_('Vienna',_'Milan')
#  + x_('Warsaw',_'Milan') = 1
#
# _C28: x_('Milan',_'Barcelona') + x_('Milan',_'Belgrade')
#  + x_('Milan',_'Berlin') + x_('Milan',_'Brussels') + x_('Milan',_'Bucharest')
#  + x_('Milan',_'Budapest') + x_('Milan',_'Copenhagen') + x_('Milan',_'Dublin')
#  + x_('Milan',_'Hamburg') + x_('Milan',_'Istanbul') + x_('Milan',_'Kiev')
#  + x_('Milan',_'London') + x_('Milan',_'Madrid') + x_('Milan',_'Moscow')
#  + x_('Milan',_'Munich') + x_('Milan',_'Paris') + x_('Milan',_'Prague')
#  + x_('Milan',_'Rome') + x_('Milan',_'Saint_Petersburg')
#  + x_('Milan',_'Sofia') + x_('Milan',_'Stockholm') + x_('Milan',_'Vienna')
#  + x_('Milan',_'Warsaw') = 1
#
# _C29: x_('Barcelona',_'Moscow') + x_('Belgrade',_'Moscow')
#  + x_('Berlin',_'Moscow') + x_('Brussels',_'Moscow')
#  + x_('Bucharest',_'Moscow') + x_('Budapest',_'Moscow')
#  + x_('Copenhagen',_'Moscow') + x_('Dublin',_'Moscow')
#  + x_('Hamburg',_'Moscow') + x_('Istanbul',_'Moscow') + x_('Kiev',_'Moscow')
#  + x_('London',_'Moscow') + x_('Madrid',_'Moscow') + x_('Milan',_'Moscow')
#  + x_('Munich',_'Moscow') + x_('Paris',_'Moscow') + x_('Prague',_'Moscow')
#  + x_('Rome',_'Moscow') + x_('Saint_Petersburg',_'Moscow')
#  + x_('Sofia',_'Moscow') + x_('Stockholm',_'Moscow') + x_('Vienna',_'Moscow')
#  + x_('Warsaw',_'Moscow') = 1
#
# _C30: x_('Moscow',_'Barcelona') + x_('Moscow',_'Belgrade')
#  + x_('Moscow',_'Berlin') + x_('Moscow',_'Brussels')
#  + x_('Moscow',_'Bucharest') + x_('Moscow',_'Budapest')
#  + x_('Moscow',_'Copenhagen') + x_('Moscow',_'Dublin')
#  + x_('Moscow',_'Hamburg') + x_('Moscow',_'Istanbul') + x_('Moscow',_'Kiev')
#  + x_('Moscow',_'London') + x_('Moscow',_'Madrid') + x_('Moscow',_'Milan')
#  + x_('Moscow',_'Munich') + x_('Moscow',_'Paris') + x_('Moscow',_'Prague')
#  + x_('Moscow',_'Rome') + x_('Moscow',_'Saint_Petersburg')
#  + x_('Moscow',_'Sofia') + x_('Moscow',_'Stockholm') + x_('Moscow',_'Vienna')
#  + x_('Moscow',_'Warsaw') = 1
#
# _C31: x_('Barcelona',_'Munich') + x_('Belgrade',_'Munich')
#  + x_('Berlin',_'Munich') + x_('Brussels',_'Munich')
#  + x_('Bucharest',_'Munich') + x_('Budapest',_'Munich')
#  + x_('Copenhagen',_'Munich') + x_('Dublin',_'Munich')
#  + x_('Hamburg',_'Munich') + x_('Istanbul',_'Munich') + x_('Kiev',_'Munich')
#  + x_('London',_'Munich') + x_('Madrid',_'Munich') + x_('Milan',_'Munich')
#  + x_('Moscow',_'Munich') + x_('Paris',_'Munich') + x_('Prague',_'Munich')
#  + x_('Rome',_'Munich') + x_('Saint_Petersburg',_'Munich')
#  + x_('Sofia',_'Munich') + x_('Stockholm',_'Munich') + x_('Vienna',_'Munich')
#  + x_('Warsaw',_'Munich') = 1
#
# _C32: x_('Munich',_'Barcelona') + x_('Munich',_'Belgrade')
#  + x_('Munich',_'Berlin') + x_('Munich',_'Brussels')
#  + x_('Munich',_'Bucharest') + x_('Munich',_'Budapest')
#  + x_('Munich',_'Copenhagen') + x_('Munich',_'Dublin')
#  + x_('Munich',_'Hamburg') + x_('Munich',_'Istanbul') + x_('Munich',_'Kiev')
#  + x_('Munich',_'London') + x_('Munich',_'Madrid') + x_('Munich',_'Milan')
#  + x_('Munich',_'Moscow') + x_('Munich',_'Paris') + x_('Munich',_'Prague')
#  + x_('Munich',_'Rome') + x_('Munich',_'Saint_Petersburg')
#  + x_('Munich',_'Sofia') + x_('Munich',_'Stockholm') + x_('Munich',_'Vienna')
#  + x_('Munich',_'Warsaw') = 1
#
# _C33: x_('Barcelona',_'Paris') + x_('Belgrade',_'Paris')
#  + x_('Berlin',_'Paris') + x_('Brussels',_'Paris') + x_('Bucharest',_'Paris')
#  + x_('Budapest',_'Paris') + x_('Copenhagen',_'Paris') + x_('Dublin',_'Paris')
#  + x_('Hamburg',_'Paris') + x_('Istanbul',_'Paris') + x_('Kiev',_'Paris')
#  + x_('London',_'Paris') + x_('Madrid',_'Paris') + x_('Milan',_'Paris')
#  + x_('Moscow',_'Paris') + x_('Munich',_'Paris') + x_('Prague',_'Paris')
#  + x_('Rome',_'Paris') + x_('Saint_Petersburg',_'Paris')
#  + x_('Sofia',_'Paris') + x_('Stockholm',_'Paris') + x_('Vienna',_'Paris')
#  + x_('Warsaw',_'Paris') = 1
#
# _C34: x_('Paris',_'Barcelona') + x_('Paris',_'Belgrade')
#  + x_('Paris',_'Berlin') + x_('Paris',_'Brussels') + x_('Paris',_'Bucharest')
#  + x_('Paris',_'Budapest') + x_('Paris',_'Copenhagen') + x_('Paris',_'Dublin')
#  + x_('Paris',_'Hamburg') + x_('Paris',_'Istanbul') + x_('Paris',_'Kiev')
#  + x_('Paris',_'London') + x_('Paris',_'Madrid') + x_('Paris',_'Milan')
#  + x_('Paris',_'Moscow') + x_('Paris',_'Munich') + x_('Paris',_'Prague')
#  + x_('Paris',_'Rome') + x_('Paris',_'Saint_Petersburg')
#  + x_('Paris',_'Sofia') + x_('Paris',_'Stockholm') + x_('Paris',_'Vienna')
#  + x_('Paris',_'Warsaw') = 1
#
# _C35: x_('Barcelona',_'Prague') + x_('Belgrade',_'Prague')
#  + x_('Berlin',_'Prague') + x_('Brussels',_'Prague')
#  + x_('Bucharest',_'Prague') + x_('Budapest',_'Prague')
#  + x_('Copenhagen',_'Prague') + x_('Dublin',_'Prague')
#  + x_('Hamburg',_'Prague') + x_('Istanbul',_'Prague') + x_('Kiev',_'Prague')
#  + x_('London',_'Prague') + x_('Madrid',_'Prague') + x_('Milan',_'Prague')
#  + x_('Moscow',_'Prague') + x_('Munich',_'Prague') + x_('Paris',_'Prague')
#  + x_('Rome',_'Prague') + x_('Saint_Petersburg',_'Prague')
#  + x_('Sofia',_'Prague') + x_('Stockholm',_'Prague') + x_('Vienna',_'Prague')
#  + x_('Warsaw',_'Prague') = 1
#
# _C36: x_('Prague',_'Barcelona') + x_('Prague',_'Belgrade')
#  + x_('Prague',_'Berlin') + x_('Prague',_'Brussels')
#  + x_('Prague',_'Bucharest') + x_('Prague',_'Budapest')
#  + x_('Prague',_'Copenhagen') + x_('Prague',_'Dublin')
#  + x_('Prague',_'Hamburg') + x_('Prague',_'Istanbul') + x_('Prague',_'Kiev')
#  + x_('Prague',_'London') + x_('Prague',_'Madrid') + x_('Prague',_'Milan')
#  + x_('Prague',_'Moscow') + x_('Prague',_'Munich') + x_('Prague',_'Paris')
#  + x_('Prague',_'Rome') + x_('Prague',_'Saint_Petersburg')
#  + x_('Prague',_'Sofia') + x_('Prague',_'Stockholm') + x_('Prague',_'Vienna')
#  + x_('Prague',_'Warsaw') = 1
#
# _C37: x_('Barcelona',_'Rome') + x_('Belgrade',_'Rome') + x_('Berlin',_'Rome')
#  + x_('Brussels',_'Rome') + x_('Bucharest',_'Rome') + x_('Budapest',_'Rome')
#  + x_('Copenhagen',_'Rome') + x_('Dublin',_'Rome') + x_('Hamburg',_'Rome')
#  + x_('Istanbul',_'Rome') + x_('Kiev',_'Rome') + x_('London',_'Rome')
#  + x_('Madrid',_'Rome') + x_('Milan',_'Rome') + x_('Moscow',_'Rome')
#  + x_('Munich',_'Rome') + x_('Paris',_'Rome') + x_('Prague',_'Rome')
#  + x_('Saint_Petersburg',_'Rome') + x_('Sofia',_'Rome')
#  + x_('Stockholm',_'Rome') + x_('Vienna',_'Rome') + x_('Warsaw',_'Rome') = 1
#
# _C38: x_('Rome',_'Barcelona') + x_('Rome',_'Belgrade') + x_('Rome',_'Berlin')
#  + x_('Rome',_'Brussels') + x_('Rome',_'Bucharest') + x_('Rome',_'Budapest')
#  + x_('Rome',_'Copenhagen') + x_('Rome',_'Dublin') + x_('Rome',_'Hamburg')
#  + x_('Rome',_'Istanbul') + x_('Rome',_'Kiev') + x_('Rome',_'London')
#  + x_('Rome',_'Madrid') + x_('Rome',_'Milan') + x_('Rome',_'Moscow')
#  + x_('Rome',_'Munich') + x_('Rome',_'Paris') + x_('Rome',_'Prague')
#  + x_('Rome',_'Saint_Petersburg') + x_('Rome',_'Sofia')
#  + x_('Rome',_'Stockholm') + x_('Rome',_'Vienna') + x_('Rome',_'Warsaw') = 1
#
# _C39: x_('Barcelona',_'Saint_Petersburg') + x_('Belgrade',_'Saint_Petersburg')
#  + x_('Berlin',_'Saint_Petersburg') + x_('Brussels',_'Saint_Petersburg')
#  + x_('Bucharest',_'Saint_Petersburg') + x_('Budapest',_'Saint_Petersburg')
#  + x_('Copenhagen',_'Saint_Petersburg') + x_('Dublin',_'Saint_Petersburg')
#  + x_('Hamburg',_'Saint_Petersburg') + x_('Istanbul',_'Saint_Petersburg')
#  + x_('Kiev',_'Saint_Petersburg') + x_('London',_'Saint_Petersburg')
#  + x_('Madrid',_'Saint_Petersburg') + x_('Milan',_'Saint_Petersburg')
#  + x_('Moscow',_'Saint_Petersburg') + x_('Munich',_'Saint_Petersburg')
#  + x_('Paris',_'Saint_Petersburg') + x_('Prague',_'Saint_Petersburg')
#  + x_('Rome',_'Saint_Petersburg') + x_('Sofia',_'Saint_Petersburg')
#  + x_('Stockholm',_'Saint_Petersburg') + x_('Vienna',_'Saint_Petersburg')
#  + x_('Warsaw',_'Saint_Petersburg') = 1
#
# _C40: x_('Saint_Petersburg',_'Barcelona') + x_('Saint_Petersburg',_'Belgrade')
#  + x_('Saint_Petersburg',_'Berlin') + x_('Saint_Petersburg',_'Brussels')
#  + x_('Saint_Petersburg',_'Bucharest') + x_('Saint_Petersburg',_'Budapest')
#  + x_('Saint_Petersburg',_'Copenhagen') + x_('Saint_Petersburg',_'Dublin')
#  + x_('Saint_Petersburg',_'Hamburg') + x_('Saint_Petersburg',_'Istanbul')
#  + x_('Saint_Petersburg',_'Kiev') + x_('Saint_Petersburg',_'London')
#  + x_('Saint_Petersburg',_'Madrid') + x_('Saint_Petersburg',_'Milan')
#  + x_('Saint_Petersburg',_'Moscow') + x_('Saint_Petersburg',_'Munich')
#  + x_('Saint_Petersburg',_'Paris') + x_('Saint_Petersburg',_'Prague')
#  + x_('Saint_Petersburg',_'Rome') + x_('Saint_Petersburg',_'Sofia')
#  + x_('Saint_Petersburg',_'Stockholm') + x_('Saint_Petersburg',_'Vienna')
#  + x_('Saint_Petersburg',_'Warsaw') = 1
#
# _C41: x_('Barcelona',_'Sofia') + x_('Belgrade',_'Sofia')
#  + x_('Berlin',_'Sofia') + x_('Brussels',_'Sofia') + x_('Bucharest',_'Sofia')
#  + x_('Budapest',_'Sofia') + x_('Copenhagen',_'Sofia') + x_('Dublin',_'Sofia')
#  + x_('Hamburg',_'Sofia') + x_('Istanbul',_'Sofia') + x_('Kiev',_'Sofia')
#  + x_('London',_'Sofia') + x_('Madrid',_'Sofia') + x_('Milan',_'Sofia')
#  + x_('Moscow',_'Sofia') + x_('Munich',_'Sofia') + x_('Paris',_'Sofia')
#  + x_('Prague',_'Sofia') + x_('Rome',_'Sofia')
#  + x_('Saint_Petersburg',_'Sofia') + x_('Stockholm',_'Sofia')
#  + x_('Vienna',_'Sofia') + x_('Warsaw',_'Sofia') = 1
#
# _C42: x_('Sofia',_'Barcelona') + x_('Sofia',_'Belgrade')
#  + x_('Sofia',_'Berlin') + x_('Sofia',_'Brussels') + x_('Sofia',_'Bucharest')
#  + x_('Sofia',_'Budapest') + x_('Sofia',_'Copenhagen') + x_('Sofia',_'Dublin')
#  + x_('Sofia',_'Hamburg') + x_('Sofia',_'Istanbul') + x_('Sofia',_'Kiev')
#  + x_('Sofia',_'London') + x_('Sofia',_'Madrid') + x_('Sofia',_'Milan')
#  + x_('Sofia',_'Moscow') + x_('Sofia',_'Munich') + x_('Sofia',_'Paris')
#  + x_('Sofia',_'Prague') + x_('Sofia',_'Rome')
#  + x_('Sofia',_'Saint_Petersburg') + x_('Sofia',_'Stockholm')
#  + x_('Sofia',_'Vienna') + x_('Sofia',_'Warsaw') = 1
#
# _C43: x_('Barcelona',_'Stockholm') + x_('Belgrade',_'Stockholm')
#  + x_('Berlin',_'Stockholm') + x_('Brussels',_'Stockholm')
#  + x_('Bucharest',_'Stockholm') + x_('Budapest',_'Stockholm')
#  + x_('Copenhagen',_'Stockholm') + x_('Dublin',_'Stockholm')
#  + x_('Hamburg',_'Stockholm') + x_('Istanbul',_'Stockholm')
#  + x_('Kiev',_'Stockholm') + x_('London',_'Stockholm')
#  + x_('Madrid',_'Stockholm') + x_('Milan',_'Stockholm')
#  + x_('Moscow',_'Stockholm') + x_('Munich',_'Stockholm')
#  + x_('Paris',_'Stockholm') + x_('Prague',_'Stockholm')
#  + x_('Rome',_'Stockholm') + x_('Saint_Petersburg',_'Stockholm')
#  + x_('Sofia',_'Stockholm') + x_('Vienna',_'Stockholm')
#  + x_('Warsaw',_'Stockholm') = 1
#
# _C44: x_('Stockholm',_'Barcelona') + x_('Stockholm',_'Belgrade')
#  + x_('Stockholm',_'Berlin') + x_('Stockholm',_'Brussels')
#  + x_('Stockholm',_'Bucharest') + x_('Stockholm',_'Budapest')
#  + x_('Stockholm',_'Copenhagen') + x_('Stockholm',_'Dublin')
#  + x_('Stockholm',_'Hamburg') + x_('Stockholm',_'Istanbul')
#  + x_('Stockholm',_'Kiev') + x_('Stockholm',_'London')
#  + x_('Stockholm',_'Madrid') + x_('Stockholm',_'Milan')
#  + x_('Stockholm',_'Moscow') + x_('Stockholm',_'Munich')
#  + x_('Stockholm',_'Paris') + x_('Stockholm',_'Prague')
#  + x_('Stockholm',_'Rome') + x_('Stockholm',_'Saint_Petersburg')
#  + x_('Stockholm',_'Sofia') + x_('Stockholm',_'Vienna')
#  + x_('Stockholm',_'Warsaw') = 1
#
# _C45: x_('Barcelona',_'Vienna') + x_('Belgrade',_'Vienna')
#  + x_('Berlin',_'Vienna') + x_('Brussels',_'Vienna')
#  + x_('Bucharest',_'Vienna') + x_('Budapest',_'Vienna')
#  + x_('Copenhagen',_'Vienna') + x_('Dublin',_'Vienna')
#  + x_('Hamburg',_'Vienna') + x_('Istanbul',_'Vienna') + x_('Kiev',_'Vienna')
#  + x_('London',_'Vienna') + x_('Madrid',_'Vienna') + x_('Milan',_'Vienna')
#  + x_('Moscow',_'Vienna') + x_('Munich',_'Vienna') + x_('Paris',_'Vienna')
#  + x_('Prague',_'Vienna') + x_('Rome',_'Vienna')
#  + x_('Saint_Petersburg',_'Vienna') + x_('Sofia',_'Vienna')
#  + x_('Stockholm',_'Vienna') + x_('Warsaw',_'Vienna') = 1
#
# _C46: x_('Vienna',_'Barcelona') + x_('Vienna',_'Belgrade')
#  + x_('Vienna',_'Berlin') + x_('Vienna',_'Brussels')
#  + x_('Vienna',_'Bucharest') + x_('Vienna',_'Budapest')
#  + x_('Vienna',_'Copenhagen') + x_('Vienna',_'Dublin')
#  + x_('Vienna',_'Hamburg') + x_('Vienna',_'Istanbul') + x_('Vienna',_'Kiev')
#  + x_('Vienna',_'London') + x_('Vienna',_'Madrid') + x_('Vienna',_'Milan')
#  + x_('Vienna',_'Moscow') + x_('Vienna',_'Munich') + x_('Vienna',_'Paris')
#  + x_('Vienna',_'Prague') + x_('Vienna',_'Rome')
#  + x_('Vienna',_'Saint_Petersburg') + x_('Vienna',_'Sofia')
#  + x_('Vienna',_'Stockholm') + x_('Vienna',_'Warsaw') = 1
#
# _C47: x_('Barcelona',_'Warsaw') + x_('Belgrade',_'Warsaw')
#  + x_('Berlin',_'Warsaw') + x_('Brussels',_'Warsaw')
#  + x_('Bucharest',_'Warsaw') + x_('Budapest',_'Warsaw')
#  + x_('Copenhagen',_'Warsaw') + x_('Dublin',_'Warsaw')
#  + x_('Hamburg',_'Warsaw') + x_('Istanbul',_'Warsaw') + x_('Kiev',_'Warsaw')
#  + x_('London',_'Warsaw') + x_('Madrid',_'Warsaw') + x_('Milan',_'Warsaw')
#  + x_('Moscow',_'Warsaw') + x_('Munich',_'Warsaw') + x_('Paris',_'Warsaw')
#  + x_('Prague',_'Warsaw') + x_('Rome',_'Warsaw')
#  + x_('Saint_Petersburg',_'Warsaw') + x_('Sofia',_'Warsaw')
#  + x_('Stockholm',_'Warsaw') + x_('Vienna',_'Warsaw') = 1
#
# _C48: x_('Warsaw',_'Barcelona') + x_('Warsaw',_'Belgrade')
#  + x_('Warsaw',_'Berlin') + x_('Warsaw',_'Brussels')
#  + x_('Warsaw',_'Bucharest') + x_('Warsaw',_'Budapest')
#  + x_('Warsaw',_'Copenhagen') + x_('Warsaw',_'Dublin')
#  + x_('Warsaw',_'Hamburg') + x_('Warsaw',_'Istanbul') + x_('Warsaw',_'Kiev')
#  + x_('Warsaw',_'London') + x_('Warsaw',_'Madrid') + x_('Warsaw',_'Milan')
#  + x_('Warsaw',_'Moscow') + x_('Warsaw',_'Munich') + x_('Warsaw',_'Paris')
#  + x_('Warsaw',_'Prague') + x_('Warsaw',_'Rome')
#  + x_('Warsaw',_'Saint_Petersburg') + x_('Warsaw',_'Sofia')
#  + x_('Warsaw',_'Stockholm') + x_('Warsaw',_'Vienna') = 1
#
# _C49: u_Barcelona - u_Belgrade + 6 x_('Barcelona',_'Belgrade') <= 5
#
# _C50: u_Barcelona - u_Brussels + 6 x_('Barcelona',_'Brussels') <= 5
#
# _C51: u_Barcelona - u_Bucharest + 6 x_('Barcelona',_'Bucharest') <= 5
#
# _C52: u_Barcelona - u_Budapest + 6 x_('Barcelona',_'Budapest') <= 5
#
# _C53: u_Barcelona - u_Copenhagen + 6 x_('Barcelona',_'Copenhagen') <= 5
#
# _C54: u_Barcelona - u_Dublin + 6 x_('Barcelona',_'Dublin') <= 5
#
# _C55: u_Barcelona - u_Hamburg + 6 x_('Barcelona',_'Hamburg') <= 5
#
# _C56: u_Barcelona - u_Istanbul + 6 x_('Barcelona',_'Istanbul') <= 5
#
# _C57: u_Barcelona - u_Kiev + 6 x_('Barcelona',_'Kiev') <= 5
#
# _C58: u_Barcelona - u_London + 6 x_('Barcelona',_'London') <= 5
#
# _C59: u_Barcelona - u_Madrid + 6 x_('Barcelona',_'Madrid') <= 5
#
# _C60: u_Barcelona - u_Milan + 6 x_('Barcelona',_'Milan') <= 5
#
# _C61: u_Barcelona - u_Moscow + 6 x_('Barcelona',_'Moscow') <= 5
#
# _C62: u_Barcelona - u_Munich + 6 x_('Barcelona',_'Munich') <= 5
#
# _C63: u_Barcelona - u_Paris + 6 x_('Barcelona',_'Paris') <= 5
#
# _C64: u_Barcelona - u_Prague + 6 x_('Barcelona',_'Prague') <= 5
#
# _C65: u_Barcelona - u_Rome + 6 x_('Barcelona',_'Rome') <= 5
#
# _C66: u_Barcelona - u_Saint_Petersburg + 6 x_('Barcelona',_'Saint_Petersburg')
#  <= 5
#
# _C67: u_Barcelona - u_Sofia + 6 x_('Barcelona',_'Sofia') <= 5
#
# _C68: u_Barcelona - u_Stockholm + 6 x_('Barcelona',_'Stockholm') <= 5
#
# _C69: u_Barcelona - u_Vienna + 6 x_('Barcelona',_'Vienna') <= 5
#
# _C70: u_Barcelona - u_Warsaw + 6 x_('Barcelona',_'Warsaw') <= 5
#
# _C71: - u_Barcelona + u_Belgrade + 6 x_('Belgrade',_'Barcelona') <= 5
#
# _C72: u_Belgrade - u_Brussels + 6 x_('Belgrade',_'Brussels') <= 5
#
# _C73: u_Belgrade - u_Bucharest + 6 x_('Belgrade',_'Bucharest') <= 5
#
# _C74: u_Belgrade - u_Budapest + 6 x_('Belgrade',_'Budapest') <= 5
#
# _C75: u_Belgrade - u_Copenhagen + 6 x_('Belgrade',_'Copenhagen') <= 5
#
# _C76: u_Belgrade - u_Dublin + 6 x_('Belgrade',_'Dublin') <= 5
#
# _C77: u_Belgrade - u_Hamburg + 6 x_('Belgrade',_'Hamburg') <= 5
#
# _C78: u_Belgrade - u_Istanbul + 6 x_('Belgrade',_'Istanbul') <= 5
#
# _C79: u_Belgrade - u_Kiev + 6 x_('Belgrade',_'Kiev') <= 5
#
# _C80: u_Belgrade - u_London + 6 x_('Belgrade',_'London') <= 5
#
# _C81: u_Belgrade - u_Madrid + 6 x_('Belgrade',_'Madrid') <= 5
#
# _C82: u_Belgrade - u_Milan + 6 x_('Belgrade',_'Milan') <= 5
#
# _C83: u_Belgrade - u_Moscow + 6 x_('Belgrade',_'Moscow') <= 5
#
# _C84: u_Belgrade - u_Munich + 6 x_('Belgrade',_'Munich') <= 5
#
# _C85: u_Belgrade - u_Paris + 6 x_('Belgrade',_'Paris') <= 5
#
# _C86: u_Belgrade - u_Prague + 6 x_('Belgrade',_'Prague') <= 5
#
# _C87: u_Belgrade - u_Rome + 6 x_('Belgrade',_'Rome') <= 5
#
# _C88: u_Belgrade - u_Saint_Petersburg + 6 x_('Belgrade',_'Saint_Petersburg')
#  <= 5
#
# _C89: u_Belgrade - u_Sofia + 6 x_('Belgrade',_'Sofia') <= 5
#
# _C90: u_Belgrade - u_Stockholm + 6 x_('Belgrade',_'Stockholm') <= 5
#
# _C91: u_Belgrade - u_Vienna + 6 x_('Belgrade',_'Vienna') <= 5
#
# _C92: u_Belgrade - u_Warsaw + 6 x_('Belgrade',_'Warsaw') <= 5
#
# _C93: - u_Barcelona + u_Brussels + 6 x_('Brussels',_'Barcelona') <= 5
#
# _C94: - u_Belgrade + u_Brussels + 6 x_('Brussels',_'Belgrade') <= 5
#
# _C95: u_Brussels - u_Bucharest + 6 x_('Brussels',_'Bucharest') <= 5
#
# _C96: u_Brussels - u_Budapest + 6 x_('Brussels',_'Budapest') <= 5
#
# _C97: u_Brussels - u_Copenhagen + 6 x_('Brussels',_'Copenhagen') <= 5
#
# _C98: u_Brussels - u_Dublin + 6 x_('Brussels',_'Dublin') <= 5
#
# _C99: u_Brussels - u_Hamburg + 6 x_('Brussels',_'Hamburg') <= 5
#
# _C100: u_Brussels - u_Istanbul + 6 x_('Brussels',_'Istanbul') <= 5
#
# _C101: u_Brussels - u_Kiev + 6 x_('Brussels',_'Kiev') <= 5
#
# _C102: u_Brussels - u_London + 6 x_('Brussels',_'London') <= 5
#
# _C103: u_Brussels - u_Madrid + 6 x_('Brussels',_'Madrid') <= 5
#
# _C104: u_Brussels - u_Milan + 6 x_('Brussels',_'Milan') <= 5
#
# _C105: u_Brussels - u_Moscow + 6 x_('Brussels',_'Moscow') <= 5
#
# _C106: u_Brussels - u_Munich + 6 x_('Brussels',_'Munich') <= 5
#
# _C107: u_Brussels - u_Paris + 6 x_('Brussels',_'Paris') <= 5
#
# _C108: u_Brussels - u_Prague + 6 x_('Brussels',_'Prague') <= 5
#
# _C109: u_Brussels - u_Rome + 6 x_('Brussels',_'Rome') <= 5
#
# _C110: u_Brussels - u_Saint_Petersburg + 6 x_('Brussels',_'Saint_Petersburg')
#  <= 5
#
# _C111: u_Brussels - u_Sofia + 6 x_('Brussels',_'Sofia') <= 5
#
# _C112: u_Brussels - u_Stockholm + 6 x_('Brussels',_'Stockholm') <= 5
#
# _C113: u_Brussels - u_Vienna + 6 x_('Brussels',_'Vienna') <= 5
#
# _C114: u_Brussels - u_Warsaw + 6 x_('Brussels',_'Warsaw') <= 5
#
# _C115: - u_Barcelona + u_Bucharest + 6 x_('Bucharest',_'Barcelona') <= 5
#
# _C116: - u_Belgrade + u_Bucharest + 6 x_('Bucharest',_'Belgrade') <= 5
#
# _C117: - u_Brussels + u_Bucharest + 6 x_('Bucharest',_'Brussels') <= 5
#
# _C118: u_Bucharest - u_Budapest + 6 x_('Bucharest',_'Budapest') <= 5
#
# _C119: u_Bucharest - u_Copenhagen + 6 x_('Bucharest',_'Copenhagen') <= 5
#
# _C120: u_Bucharest - u_Dublin + 6 x_('Bucharest',_'Dublin') <= 5
#
# _C121: u_Bucharest - u_Hamburg + 6 x_('Bucharest',_'Hamburg') <= 5
#
# _C122: u_Bucharest - u_Istanbul + 6 x_('Bucharest',_'Istanbul') <= 5
#
# _C123: u_Bucharest - u_Kiev + 6 x_('Bucharest',_'Kiev') <= 5
#
# _C124: u_Bucharest - u_London + 6 x_('Bucharest',_'London') <= 5
#
# _C125: u_Bucharest - u_Madrid + 6 x_('Bucharest',_'Madrid') <= 5
#
# _C126: u_Bucharest - u_Milan + 6 x_('Bucharest',_'Milan') <= 5
#
# _C127: u_Bucharest - u_Moscow + 6 x_('Bucharest',_'Moscow') <= 5
#
# _C128: u_Bucharest - u_Munich + 6 x_('Bucharest',_'Munich') <= 5
#
# _C129: u_Bucharest - u_Paris + 6 x_('Bucharest',_'Paris') <= 5
#
# _C130: u_Bucharest - u_Prague + 6 x_('Bucharest',_'Prague') <= 5
#
# _C131: u_Bucharest - u_Rome + 6 x_('Bucharest',_'Rome') <= 5
#
# _C132: u_Bucharest - u_Saint_Petersburg
#  + 6 x_('Bucharest',_'Saint_Petersburg') <= 5
#
# _C133: u_Bucharest - u_Sofia + 6 x_('Bucharest',_'Sofia') <= 5
#
# _C134: u_Bucharest - u_Stockholm + 6 x_('Bucharest',_'Stockholm') <= 5
#
# _C135: u_Bucharest - u_Vienna + 6 x_('Bucharest',_'Vienna') <= 5
#
# _C136: u_Bucharest - u_Warsaw + 6 x_('Bucharest',_'Warsaw') <= 5
#
# _C137: - u_Barcelona + u_Budapest + 6 x_('Budapest',_'Barcelona') <= 5
#
# _C138: - u_Belgrade + u_Budapest + 6 x_('Budapest',_'Belgrade') <= 5
#
# _C139: - u_Brussels + u_Budapest + 6 x_('Budapest',_'Brussels') <= 5
#
# _C140: - u_Bucharest + u_Budapest + 6 x_('Budapest',_'Bucharest') <= 5
#
# _C141: u_Budapest - u_Copenhagen + 6 x_('Budapest',_'Copenhagen') <= 5
#
# _C142: u_Budapest - u_Dublin + 6 x_('Budapest',_'Dublin') <= 5
#
# _C143: u_Budapest - u_Hamburg + 6 x_('Budapest',_'Hamburg') <= 5
#
# _C144: u_Budapest - u_Istanbul + 6 x_('Budapest',_'Istanbul') <= 5
#
# _C145: u_Budapest - u_Kiev + 6 x_('Budapest',_'Kiev') <= 5
#
# _C146: u_Budapest - u_London + 6 x_('Budapest',_'London') <= 5
#
# _C147: u_Budapest - u_Madrid + 6 x_('Budapest',_'Madrid') <= 5
#
# _C148: u_Budapest - u_Milan + 6 x_('Budapest',_'Milan') <= 5
#
# _C149: u_Budapest - u_Moscow + 6 x_('Budapest',_'Moscow') <= 5
#
# _C150: u_Budapest - u_Munich + 6 x_('Budapest',_'Munich') <= 5
#
# _C151: u_Budapest - u_Paris + 6 x_('Budapest',_'Paris') <= 5
#
# _C152: u_Budapest - u_Prague + 6 x_('Budapest',_'Prague') <= 5
#
# _C153: u_Budapest - u_Rome + 6 x_('Budapest',_'Rome') <= 5
#
# _C154: u_Budapest - u_Saint_Petersburg + 6 x_('Budapest',_'Saint_Petersburg')
#  <= 5
#
# _C155: u_Budapest - u_Sofia + 6 x_('Budapest',_'Sofia') <= 5
#
# _C156: u_Budapest - u_Stockholm + 6 x_('Budapest',_'Stockholm') <= 5
#
# _C157: u_Budapest - u_Vienna + 6 x_('Budapest',_'Vienna') <= 5
#
# _C158: u_Budapest - u_Warsaw + 6 x_('Budapest',_'Warsaw') <= 5
#
# _C159: - u_Barcelona + u_Copenhagen + 6 x_('Copenhagen',_'Barcelona') <= 5
#
# _C160: - u_Belgrade + u_Copenhagen + 6 x_('Copenhagen',_'Belgrade') <= 5
#
# _C161: - u_Brussels + u_Copenhagen + 6 x_('Copenhagen',_'Brussels') <= 5
#
# _C162: - u_Bucharest + u_Copenhagen + 6 x_('Copenhagen',_'Bucharest') <= 5
#
# _C163: - u_Budapest + u_Copenhagen + 6 x_('Copenhagen',_'Budapest') <= 5
#
# _C164: u_Copenhagen - u_Dublin + 6 x_('Copenhagen',_'Dublin') <= 5
#
# _C165: u_Copenhagen - u_Hamburg + 6 x_('Copenhagen',_'Hamburg') <= 5
#
# _C166: u_Copenhagen - u_Istanbul + 6 x_('Copenhagen',_'Istanbul') <= 5
#
# _C167: u_Copenhagen - u_Kiev + 6 x_('Copenhagen',_'Kiev') <= 5
#
# _C168: u_Copenhagen - u_London + 6 x_('Copenhagen',_'London') <= 5
#
# _C169: u_Copenhagen - u_Madrid + 6 x_('Copenhagen',_'Madrid') <= 5
#
# _C170: u_Copenhagen - u_Milan + 6 x_('Copenhagen',_'Milan') <= 5
#
# _C171: u_Copenhagen - u_Moscow + 6 x_('Copenhagen',_'Moscow') <= 5
#
# _C172: u_Copenhagen - u_Munich + 6 x_('Copenhagen',_'Munich') <= 5
#
# _C173: u_Copenhagen - u_Paris + 6 x_('Copenhagen',_'Paris') <= 5
#
# _C174: u_Copenhagen - u_Prague + 6 x_('Copenhagen',_'Prague') <= 5
#
# _C175: u_Copenhagen - u_Rome + 6 x_('Copenhagen',_'Rome') <= 5
#
# _C176: u_Copenhagen - u_Saint_Petersburg
#  + 6 x_('Copenhagen',_'Saint_Petersburg') <= 5
#
# _C177: u_Copenhagen - u_Sofia + 6 x_('Copenhagen',_'Sofia') <= 5
#
# _C178: u_Copenhagen - u_Stockholm + 6 x_('Copenhagen',_'Stockholm') <= 5
#
# _C179: u_Copenhagen - u_Vienna + 6 x_('Copenhagen',_'Vienna') <= 5
#
# _C180: u_Copenhagen - u_Warsaw + 6 x_('Copenhagen',_'Warsaw') <= 5
#
# _C181: - u_Barcelona + u_Dublin + 6 x_('Dublin',_'Barcelona') <= 5
#
# _C182: - u_Belgrade + u_Dublin + 6 x_('Dublin',_'Belgrade') <= 5
#
# _C183: - u_Brussels + u_Dublin + 6 x_('Dublin',_'Brussels') <= 5
#
# _C184: - u_Bucharest + u_Dublin + 6 x_('Dublin',_'Bucharest') <= 5
#
# _C185: - u_Budapest + u_Dublin + 6 x_('Dublin',_'Budapest') <= 5
#
# _C186: - u_Copenhagen + u_Dublin + 6 x_('Dublin',_'Copenhagen') <= 5
#
# _C187: u_Dublin - u_Hamburg + 6 x_('Dublin',_'Hamburg') <= 5
#
# _C188: u_Dublin - u_Istanbul + 6 x_('Dublin',_'Istanbul') <= 5
#
# _C189: u_Dublin - u_Kiev + 6 x_('Dublin',_'Kiev') <= 5
#
# _C190: u_Dublin - u_London + 6 x_('Dublin',_'London') <= 5
#
# _C191: u_Dublin - u_Madrid + 6 x_('Dublin',_'Madrid') <= 5
#
# _C192: u_Dublin - u_Milan + 6 x_('Dublin',_'Milan') <= 5
#
# _C193: u_Dublin - u_Moscow + 6 x_('Dublin',_'Moscow') <= 5
#
# _C194: u_Dublin - u_Munich + 6 x_('Dublin',_'Munich') <= 5
#
# _C195: u_Dublin - u_Paris + 6 x_('Dublin',_'Paris') <= 5
#
# _C196: u_Dublin - u_Prague + 6 x_('Dublin',_'Prague') <= 5
#
# _C197: u_Dublin - u_Rome + 6 x_('Dublin',_'Rome') <= 5
#
# _C198: u_Dublin - u_Saint_Petersburg + 6 x_('Dublin',_'Saint_Petersburg') <= 5
#
# _C199: u_Dublin - u_Sofia + 6 x_('Dublin',_'Sofia') <= 5
#
# _C200: u_Dublin - u_Stockholm + 6 x_('Dublin',_'Stockholm') <= 5
#
# _C201: u_Dublin - u_Vienna + 6 x_('Dublin',_'Vienna') <= 5
#
# _C202: u_Dublin - u_Warsaw + 6 x_('Dublin',_'Warsaw') <= 5
#
# _C203: - u_Barcelona + u_Hamburg + 6 x_('Hamburg',_'Barcelona') <= 5
#
# _C204: - u_Belgrade + u_Hamburg + 6 x_('Hamburg',_'Belgrade') <= 5
#
# _C205: - u_Brussels + u_Hamburg + 6 x_('Hamburg',_'Brussels') <= 5
#
# _C206: - u_Bucharest + u_Hamburg + 6 x_('Hamburg',_'Bucharest') <= 5
#
# _C207: - u_Budapest + u_Hamburg + 6 x_('Hamburg',_'Budapest') <= 5
#
# _C208: - u_Copenhagen + u_Hamburg + 6 x_('Hamburg',_'Copenhagen') <= 5
#
# _C209: - u_Dublin + u_Hamburg + 6 x_('Hamburg',_'Dublin') <= 5
#
# _C210: u_Hamburg - u_Istanbul + 6 x_('Hamburg',_'Istanbul') <= 5
#
# _C211: u_Hamburg - u_Kiev + 6 x_('Hamburg',_'Kiev') <= 5
#
# _C212: u_Hamburg - u_London + 6 x_('Hamburg',_'London') <= 5
#
# _C213: u_Hamburg - u_Madrid + 6 x_('Hamburg',_'Madrid') <= 5
#
# _C214: u_Hamburg - u_Milan + 6 x_('Hamburg',_'Milan') <= 5
#
# _C215: u_Hamburg - u_Moscow + 6 x_('Hamburg',_'Moscow') <= 5
#
# _C216: u_Hamburg - u_Munich + 6 x_('Hamburg',_'Munich') <= 5
#
# _C217: u_Hamburg - u_Paris + 6 x_('Hamburg',_'Paris') <= 5
#
# _C218: u_Hamburg - u_Prague + 6 x_('Hamburg',_'Prague') <= 5
#
# _C219: u_Hamburg - u_Rome + 6 x_('Hamburg',_'Rome') <= 5
#
# _C220: u_Hamburg - u_Saint_Petersburg + 6 x_('Hamburg',_'Saint_Petersburg')
#  <= 5
#
# _C221: u_Hamburg - u_Sofia + 6 x_('Hamburg',_'Sofia') <= 5
#
# _C222: u_Hamburg - u_Stockholm + 6 x_('Hamburg',_'Stockholm') <= 5
#
# _C223: u_Hamburg - u_Vienna + 6 x_('Hamburg',_'Vienna') <= 5
#
# _C224: u_Hamburg - u_Warsaw + 6 x_('Hamburg',_'Warsaw') <= 5
#
# _C225: - u_Barcelona + u_Istanbul + 6 x_('Istanbul',_'Barcelona') <= 5
#
# _C226: - u_Belgrade + u_Istanbul + 6 x_('Istanbul',_'Belgrade') <= 5
#
# _C227: - u_Brussels + u_Istanbul + 6 x_('Istanbul',_'Brussels') <= 5
#
# _C228: - u_Bucharest + u_Istanbul + 6 x_('Istanbul',_'Bucharest') <= 5
#
# _C229: - u_Budapest + u_Istanbul + 6 x_('Istanbul',_'Budapest') <= 5
#
# _C230: - u_Copenhagen + u_Istanbul + 6 x_('Istanbul',_'Copenhagen') <= 5
#
# _C231: - u_Dublin + u_Istanbul + 6 x_('Istanbul',_'Dublin') <= 5
#
# _C232: - u_Hamburg + u_Istanbul + 6 x_('Istanbul',_'Hamburg') <= 5
#
# _C233: u_Istanbul - u_Kiev + 6 x_('Istanbul',_'Kiev') <= 5
#
# _C234: u_Istanbul - u_London + 6 x_('Istanbul',_'London') <= 5
#
# _C235: u_Istanbul - u_Madrid + 6 x_('Istanbul',_'Madrid') <= 5
#
# _C236: u_Istanbul - u_Milan + 6 x_('Istanbul',_'Milan') <= 5
#
# _C237: u_Istanbul - u_Moscow + 6 x_('Istanbul',_'Moscow') <= 5
#
# _C238: u_Istanbul - u_Munich + 6 x_('Istanbul',_'Munich') <= 5
#
# _C239: u_Istanbul - u_Paris + 6 x_('Istanbul',_'Paris') <= 5
#
# _C240: u_Istanbul - u_Prague + 6 x_('Istanbul',_'Prague') <= 5
#
# _C241: u_Istanbul - u_Rome + 6 x_('Istanbul',_'Rome') <= 5
#
# _C242: u_Istanbul - u_Saint_Petersburg + 6 x_('Istanbul',_'Saint_Petersburg')
#  <= 5
#
# _C243: u_Istanbul - u_Sofia + 6 x_('Istanbul',_'Sofia') <= 5
#
# _C244: u_Istanbul - u_Stockholm + 6 x_('Istanbul',_'Stockholm') <= 5
#
# _C245: u_Istanbul - u_Vienna + 6 x_('Istanbul',_'Vienna') <= 5
#
# _C246: u_Istanbul - u_Warsaw + 6 x_('Istanbul',_'Warsaw') <= 5
#
# ...
# 0 <= x_('Dublin',_'Prague') <= 1 Integer
# 0 <= x_('Dublin',_'Rome') <= 1 Integer
# 0 <= x_('Dublin',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Dublin',_'Sofia') <= 1 Integer
# 0 <= x_('Dublin',_'Stockholm') <= 1 Integer
# 0 <= x_('Dublin',_'Vienna') <= 1 Integer
# 0 <= x_('Dublin',_'Warsaw') <= 1 Integer
# 0 <= x_('Hamburg',_'Barcelona') <= 1 Integer
# 0 <= x_('Hamburg',_'Belgrade') <= 1 Integer
# 0 <= x_('Hamburg',_'Berlin') <= 1 Integer
# 0 <= x_('Hamburg',_'Brussels') <= 1 Integer
# 0 <= x_('Hamburg',_'Bucharest') <= 1 Integer
# 0 <= x_('Hamburg',_'Budapest') <= 1 Integer
# 0 <= x_('Hamburg',_'Copenhagen') <= 1 Integer
# 0 <= x_('Hamburg',_'Dublin') <= 1 Integer
# 0 <= x_('Hamburg',_'Istanbul') <= 1 Integer
# 0 <= x_('Hamburg',_'Kiev') <= 1 Integer
# 0 <= x_('Hamburg',_'London') <= 1 Integer
# 0 <= x_('Hamburg',_'Madrid') <= 1 Integer
# 0 <= x_('Hamburg',_'Milan') <= 1 Integer
# 0 <= x_('Hamburg',_'Moscow') <= 1 Integer
# 0 <= x_('Hamburg',_'Munich') <= 1 Integer
# 0 <= x_('Hamburg',_'Paris') <= 1 Integer
# 0 <= x_('Hamburg',_'Prague') <= 1 Integer
# 0 <= x_('Hamburg',_'Rome') <= 1 Integer
# 0 <= x_('Hamburg',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Hamburg',_'Sofia') <= 1 Integer
# 0 <= x_('Hamburg',_'Stockholm') <= 1 Integer
# 0 <= x_('Hamburg',_'Vienna') <= 1 Integer
# 0 <= x_('Hamburg',_'Warsaw') <= 1 Integer
# 0 <= x_('Istanbul',_'Barcelona') <= 1 Integer
# 0 <= x_('Istanbul',_'Belgrade') <= 1 Integer
# 0 <= x_('Istanbul',_'Berlin') <= 1 Integer
# 0 <= x_('Istanbul',_'Brussels') <= 1 Integer
# 0 <= x_('Istanbul',_'Bucharest') <= 1 Integer
# 0 <= x_('Istanbul',_'Budapest') <= 1 Integer
# 0 <= x_('Istanbul',_'Copenhagen') <= 1 Integer
# 0 <= x_('Istanbul',_'Dublin') <= 1 Integer
# 0 <= x_('Istanbul',_'Hamburg') <= 1 Integer
# 0 <= x_('Istanbul',_'Kiev') <= 1 Integer
# 0 <= x_('Istanbul',_'London') <= 1 Integer
# 0 <= x_('Istanbul',_'Madrid') <= 1 Integer
# 0 <= x_('Istanbul',_'Milan') <= 1 Integer
# 0 <= x_('Istanbul',_'Moscow') <= 1 Integer
# 0 <= x_('Istanbul',_'Munich') <= 1 Integer
# 0 <= x_('Istanbul',_'Paris') <= 1 Integer
# 0 <= x_('Istanbul',_'Prague') <= 1 Integer
# 0 <= x_('Istanbul',_'Rome') <= 1 Integer
# 0 <= x_('Istanbul',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Istanbul',_'Sofia') <= 1 Integer
# 0 <= x_('Istanbul',_'Stockholm') <= 1 Integer
# 0 <= x_('Istanbul',_'Vienna') <= 1 Integer
# 0 <= x_('Istanbul',_'Warsaw') <= 1 Integer
# 0 <= x_('Kiev',_'Barcelona') <= 1 Integer
# 0 <= x_('Kiev',_'Belgrade') <= 1 Integer
# 0 <= x_('Kiev',_'Berlin') <= 1 Integer
# 0 <= x_('Kiev',_'Brussels') <= 1 Integer
# 0 <= x_('Kiev',_'Bucharest') <= 1 Integer
# 0 <= x_('Kiev',_'Budapest') <= 1 Integer
# 0 <= x_('Kiev',_'Copenhagen') <= 1 Integer
# 0 <= x_('Kiev',_'Dublin') <= 1 Integer
# 0 <= x_('Kiev',_'Hamburg') <= 1 Integer
# 0 <= x_('Kiev',_'Istanbul') <= 1 Integer
# 0 <= x_('Kiev',_'London') <= 1 Integer
# 0 <= x_('Kiev',_'Madrid') <= 1 Integer
# 0 <= x_('Kiev',_'Milan') <= 1 Integer
# 0 <= x_('Kiev',_'Moscow') <= 1 Integer
# 0 <= x_('Kiev',_'Munich') <= 1 Integer
# 0 <= x_('Kiev',_'Paris') <= 1 Integer
# 0 <= x_('Kiev',_'Prague') <= 1 Integer
# 0 <= x_('Kiev',_'Rome') <= 1 Integer
# 0 <= x_('Kiev',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Kiev',_'Sofia') <= 1 Integer
# 0 <= x_('Kiev',_'Stockholm') <= 1 Integer
# 0 <= x_('Kiev',_'Vienna') <= 1 Integer
# 0 <= x_('Kiev',_'Warsaw') <= 1 Integer
# 0 <= x_('London',_'Barcelona') <= 1 Integer
# 0 <= x_('London',_'Belgrade') <= 1 Integer
# 0 <= x_('London',_'Berlin') <= 1 Integer
# 0 <= x_('London',_'Brussels') <= 1 Integer
# 0 <= x_('London',_'Bucharest') <= 1 Integer
# 0 <= x_('London',_'Budapest') <= 1 Integer
# 0 <= x_('London',_'Copenhagen') <= 1 Integer
# 0 <= x_('London',_'Dublin') <= 1 Integer
# 0 <= x_('London',_'Hamburg') <= 1 Integer
# 0 <= x_('London',_'Istanbul') <= 1 Integer
# 0 <= x_('London',_'Kiev') <= 1 Integer
# 0 <= x_('London',_'Madrid') <= 1 Integer
# 0 <= x_('London',_'Milan') <= 1 Integer
# 0 <= x_('London',_'Moscow') <= 1 Integer
# 0 <= x_('London',_'Munich') <= 1 Integer
# 0 <= x_('London',_'Paris') <= 1 Integer
# 0 <= x_('London',_'Prague') <= 1 Integer
# 0 <= x_('London',_'Rome') <= 1 Integer
# 0 <= x_('London',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('London',_'Sofia') <= 1 Integer
# 0 <= x_('London',_'Stockholm') <= 1 Integer
# 0 <= x_('London',_'Vienna') <= 1 Integer
# 0 <= x_('London',_'Warsaw') <= 1 Integer
# 0 <= x_('Madrid',_'Barcelona') <= 1 Integer
# 0 <= x_('Madrid',_'Belgrade') <= 1 Integer
# 0 <= x_('Madrid',_'Berlin') <= 1 Integer
# 0 <= x_('Madrid',_'Brussels') <= 1 Integer
# 0 <= x_('Madrid',_'Bucharest') <= 1 Integer
# 0 <= x_('Madrid',_'Budapest') <= 1 Integer
# 0 <= x_('Madrid',_'Copenhagen') <= 1 Integer
# 0 <= x_('Madrid',_'Dublin') <= 1 Integer
# 0 <= x_('Madrid',_'Hamburg') <= 1 Integer
# 0 <= x_('Madrid',_'Istanbul') <= 1 Integer
# 0 <= x_('Madrid',_'Kiev') <= 1 Integer
# 0 <= x_('Madrid',_'London') <= 1 Integer
# 0 <= x_('Madrid',_'Milan') <= 1 Integer
# 0 <= x_('Madrid',_'Moscow') <= 1 Integer
# 0 <= x_('Madrid',_'Munich') <= 1 Integer
# 0 <= x_('Madrid',_'Paris') <= 1 Integer
# 0 <= x_('Madrid',_'Prague') <= 1 Integer
# 0 <= x_('Madrid',_'Rome') <= 1 Integer
# 0 <= x_('Madrid',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Madrid',_'Sofia') <= 1 Integer
# 0 <= x_('Madrid',_'Stockholm') <= 1 Integer
# 0 <= x_('Madrid',_'Vienna') <= 1 Integer
# 0 <= x_('Madrid',_'Warsaw') <= 1 Integer
# 0 <= x_('Milan',_'Barcelona') <= 1 Integer
# 0 <= x_('Milan',_'Belgrade') <= 1 Integer
# 0 <= x_('Milan',_'Berlin') <= 1 Integer
# 0 <= x_('Milan',_'Brussels') <= 1 Integer
# 0 <= x_('Milan',_'Bucharest') <= 1 Integer
# 0 <= x_('Milan',_'Budapest') <= 1 Integer
# 0 <= x_('Milan',_'Copenhagen') <= 1 Integer
# 0 <= x_('Milan',_'Dublin') <= 1 Integer
# 0 <= x_('Milan',_'Hamburg') <= 1 Integer
# 0 <= x_('Milan',_'Istanbul') <= 1 Integer
# 0 <= x_('Milan',_'Kiev') <= 1 Integer
# 0 <= x_('Milan',_'London') <= 1 Integer
# 0 <= x_('Milan',_'Madrid') <= 1 Integer
# 0 <= x_('Milan',_'Moscow') <= 1 Integer
# 0 <= x_('Milan',_'Munich') <= 1 Integer
# 0 <= x_('Milan',_'Paris') <= 1 Integer
# 0 <= x_('Milan',_'Prague') <= 1 Integer
# 0 <= x_('Milan',_'Rome') <= 1 Integer
# 0 <= x_('Milan',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Milan',_'Sofia') <= 1 Integer
# 0 <= x_('Milan',_'Stockholm') <= 1 Integer
# 0 <= x_('Milan',_'Vienna') <= 1 Integer
# 0 <= x_('Milan',_'Warsaw') <= 1 Integer
# 0 <= x_('Moscow',_'Barcelona') <= 1 Integer
# 0 <= x_('Moscow',_'Belgrade') <= 1 Integer
# 0 <= x_('Moscow',_'Berlin') <= 1 Integer
# 0 <= x_('Moscow',_'Brussels') <= 1 Integer
# 0 <= x_('Moscow',_'Bucharest') <= 1 Integer
# 0 <= x_('Moscow',_'Budapest') <= 1 Integer
# 0 <= x_('Moscow',_'Copenhagen') <= 1 Integer
# 0 <= x_('Moscow',_'Dublin') <= 1 Integer
# 0 <= x_('Moscow',_'Hamburg') <= 1 Integer
# 0 <= x_('Moscow',_'Istanbul') <= 1 Integer
# 0 <= x_('Moscow',_'Kiev') <= 1 Integer
# 0 <= x_('Moscow',_'London') <= 1 Integer
# 0 <= x_('Moscow',_'Madrid') <= 1 Integer
# 0 <= x_('Moscow',_'Milan') <= 1 Integer
# 0 <= x_('Moscow',_'Munich') <= 1 Integer
# 0 <= x_('Moscow',_'Paris') <= 1 Integer
# 0 <= x_('Moscow',_'Prague') <= 1 Integer
# 0 <= x_('Moscow',_'Rome') <= 1 Integer
# 0 <= x_('Moscow',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Moscow',_'Sofia') <= 1 Integer
# 0 <= x_('Moscow',_'Stockholm') <= 1 Integer
# 0 <= x_('Moscow',_'Vienna') <= 1 Integer
# 0 <= x_('Moscow',_'Warsaw') <= 1 Integer
# 0 <= x_('Munich',_'Barcelona') <= 1 Integer
# 0 <= x_('Munich',_'Belgrade') <= 1 Integer
# 0 <= x_('Munich',_'Berlin') <= 1 Integer
# 0 <= x_('Munich',_'Brussels') <= 1 Integer
# 0 <= x_('Munich',_'Bucharest') <= 1 Integer
# 0 <= x_('Munich',_'Budapest') <= 1 Integer
# 0 <= x_('Munich',_'Copenhagen') <= 1 Integer
# 0 <= x_('Munich',_'Dublin') <= 1 Integer
# 0 <= x_('Munich',_'Hamburg') <= 1 Integer
# 0 <= x_('Munich',_'Istanbul') <= 1 Integer
# 0 <= x_('Munich',_'Kiev') <= 1 Integer
# 0 <= x_('Munich',_'London') <= 1 Integer
# 0 <= x_('Munich',_'Madrid') <= 1 Integer
# 0 <= x_('Munich',_'Milan') <= 1 Integer
# 0 <= x_('Munich',_'Moscow') <= 1 Integer
# 0 <= x_('Munich',_'Paris') <= 1 Integer
# 0 <= x_('Munich',_'Prague') <= 1 Integer
# 0 <= x_('Munich',_'Rome') <= 1 Integer
# 0 <= x_('Munich',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Munich',_'Sofia') <= 1 Integer
# 0 <= x_('Munich',_'Stockholm') <= 1 Integer
# 0 <= x_('Munich',_'Vienna') <= 1 Integer
# 0 <= x_('Munich',_'Warsaw') <= 1 Integer
# 0 <= x_('Paris',_'Barcelona') <= 1 Integer
# 0 <= x_('Paris',_'Belgrade') <= 1 Integer
# 0 <= x_('Paris',_'Berlin') <= 1 Integer
# 0 <= x_('Paris',_'Brussels') <= 1 Integer
# 0 <= x_('Paris',_'Bucharest') <= 1 Integer
# 0 <= x_('Paris',_'Budapest') <= 1 Integer
# 0 <= x_('Paris',_'Copenhagen') <= 1 Integer
# 0 <= x_('Paris',_'Dublin') <= 1 Integer
# 0 <= x_('Paris',_'Hamburg') <= 1 Integer
# 0 <= x_('Paris',_'Istanbul') <= 1 Integer
# 0 <= x_('Paris',_'Kiev') <= 1 Integer
# 0 <= x_('Paris',_'London') <= 1 Integer
# 0 <= x_('Paris',_'Madrid') <= 1 Integer
# 0 <= x_('Paris',_'Milan') <= 1 Integer
# 0 <= x_('Paris',_'Moscow') <= 1 Integer
# 0 <= x_('Paris',_'Munich') <= 1 Integer
# 0 <= x_('Paris',_'Prague') <= 1 Integer
# 0 <= x_('Paris',_'Rome') <= 1 Integer
# 0 <= x_('Paris',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Paris',_'Sofia') <= 1 Integer
# 0 <= x_('Paris',_'Stockholm') <= 1 Integer
# 0 <= x_('Paris',_'Vienna') <= 1 Integer
# 0 <= x_('Paris',_'Warsaw') <= 1 Integer
# 0 <= x_('Prague',_'Barcelona') <= 1 Integer
# 0 <= x_('Prague',_'Belgrade') <= 1 Integer
# 0 <= x_('Prague',_'Berlin') <= 1 Integer
# 0 <= x_('Prague',_'Brussels') <= 1 Integer
# 0 <= x_('Prague',_'Bucharest') <= 1 Integer
# 0 <= x_('Prague',_'Budapest') <= 1 Integer
# 0 <= x_('Prague',_'Copenhagen') <= 1 Integer
# 0 <= x_('Prague',_'Dublin') <= 1 Integer
# 0 <= x_('Prague',_'Hamburg') <= 1 Integer
# 0 <= x_('Prague',_'Istanbul') <= 1 Integer
# 0 <= x_('Prague',_'Kiev') <= 1 Integer
# 0 <= x_('Prague',_'London') <= 1 Integer
# 0 <= x_('Prague',_'Madrid') <= 1 Integer
# 0 <= x_('Prague',_'Milan') <= 1 Integer
# 0 <= x_('Prague',_'Moscow') <= 1 Integer
# 0 <= x_('Prague',_'Munich') <= 1 Integer
# 0 <= x_('Prague',_'Paris') <= 1 Integer
# 0 <= x_('Prague',_'Rome') <= 1 Integer
# 0 <= x_('Prague',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Prague',_'Sofia') <= 1 Integer
# 0 <= x_('Prague',_'Stockholm') <= 1 Integer
# 0 <= x_('Prague',_'Vienna') <= 1 Integer
# 0 <= x_('Prague',_'Warsaw') <= 1 Integer
# 0 <= x_('Rome',_'Barcelona') <= 1 Integer
# 0 <= x_('Rome',_'Belgrade') <= 1 Integer
# 0 <= x_('Rome',_'Berlin') <= 1 Integer
# 0 <= x_('Rome',_'Brussels') <= 1 Integer
# 0 <= x_('Rome',_'Bucharest') <= 1 Integer
# 0 <= x_('Rome',_'Budapest') <= 1 Integer
# 0 <= x_('Rome',_'Copenhagen') <= 1 Integer
# 0 <= x_('Rome',_'Dublin') <= 1 Integer
# 0 <= x_('Rome',_'Hamburg') <= 1 Integer
# 0 <= x_('Rome',_'Istanbul') <= 1 Integer
# 0 <= x_('Rome',_'Kiev') <= 1 Integer
# 0 <= x_('Rome',_'London') <= 1 Integer
# 0 <= x_('Rome',_'Madrid') <= 1 Integer
# 0 <= x_('Rome',_'Milan') <= 1 Integer
# 0 <= x_('Rome',_'Moscow') <= 1 Integer
# 0 <= x_('Rome',_'Munich') <= 1 Integer
# 0 <= x_('Rome',_'Paris') <= 1 Integer
# 0 <= x_('Rome',_'Prague') <= 1 Integer
# 0 <= x_('Rome',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Rome',_'Sofia') <= 1 Integer
# 0 <= x_('Rome',_'Stockholm') <= 1 Integer
# 0 <= x_('Rome',_'Vienna') <= 1 Integer
# 0 <= x_('Rome',_'Warsaw') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Barcelona') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Belgrade') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Berlin') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Brussels') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Bucharest') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Budapest') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Copenhagen') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Dublin') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Hamburg') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Istanbul') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Kiev') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'London') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Madrid') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Milan') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Moscow') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Munich') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Paris') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Prague') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Rome') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Sofia') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Stockholm') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Vienna') <= 1 Integer
# 0 <= x_('Saint_Petersburg',_'Warsaw') <= 1 Integer
# 0 <= x_('Sofia',_'Barcelona') <= 1 Integer
# 0 <= x_('Sofia',_'Belgrade') <= 1 Integer
# 0 <= x_('Sofia',_'Berlin') <= 1 Integer
# 0 <= x_('Sofia',_'Brussels') <= 1 Integer
# 0 <= x_('Sofia',_'Bucharest') <= 1 Integer
# 0 <= x_('Sofia',_'Budapest') <= 1 Integer
# 0 <= x_('Sofia',_'Copenhagen') <= 1 Integer
# 0 <= x_('Sofia',_'Dublin') <= 1 Integer
# 0 <= x_('Sofia',_'Hamburg') <= 1 Integer
# 0 <= x_('Sofia',_'Istanbul') <= 1 Integer
# 0 <= x_('Sofia',_'Kiev') <= 1 Integer
# 0 <= x_('Sofia',_'London') <= 1 Integer
# 0 <= x_('Sofia',_'Madrid') <= 1 Integer
# 0 <= x_('Sofia',_'Milan') <= 1 Integer
# 0 <= x_('Sofia',_'Moscow') <= 1 Integer
# 0 <= x_('Sofia',_'Munich') <= 1 Integer
# 0 <= x_('Sofia',_'Paris') <= 1 Integer
# 0 <= x_('Sofia',_'Prague') <= 1 Integer
# 0 <= x_('Sofia',_'Rome') <= 1 Integer
# 0 <= x_('Sofia',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Sofia',_'Stockholm') <= 1 Integer
# 0 <= x_('Sofia',_'Vienna') <= 1 Integer
# 0 <= x_('Sofia',_'Warsaw') <= 1 Integer
# 0 <= x_('Stockholm',_'Barcelona') <= 1 Integer
# 0 <= x_('Stockholm',_'Belgrade') <= 1 Integer
# 0 <= x_('Stockholm',_'Berlin') <= 1 Integer
# 0 <= x_('Stockholm',_'Brussels') <= 1 Integer
# 0 <= x_('Stockholm',_'Bucharest') <= 1 Integer
# 0 <= x_('Stockholm',_'Budapest') <= 1 Integer
# 0 <= x_('Stockholm',_'Copenhagen') <= 1 Integer
# 0 <= x_('Stockholm',_'Dublin') <= 1 Integer
# 0 <= x_('Stockholm',_'Hamburg') <= 1 Integer
# 0 <= x_('Stockholm',_'Istanbul') <= 1 Integer
# 0 <= x_('Stockholm',_'Kiev') <= 1 Integer
# 0 <= x_('Stockholm',_'London') <= 1 Integer
# 0 <= x_('Stockholm',_'Madrid') <= 1 Integer
# 0 <= x_('Stockholm',_'Milan') <= 1 Integer
# 0 <= x_('Stockholm',_'Moscow') <= 1 Integer
# 0 <= x_('Stockholm',_'Munich') <= 1 Integer
# 0 <= x_('Stockholm',_'Paris') <= 1 Integer
# 0 <= x_('Stockholm',_'Prague') <= 1 Integer
# 0 <= x_('Stockholm',_'Rome') <= 1 Integer
# 0 <= x_('Stockholm',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Stockholm',_'Sofia') <= 1 Integer
# 0 <= x_('Stockholm',_'Vienna') <= 1 Integer
# 0 <= x_('Stockholm',_'Warsaw') <= 1 Integer
# 0 <= x_('Vienna',_'Barcelona') <= 1 Integer
# 0 <= x_('Vienna',_'Belgrade') <= 1 Integer
# 0 <= x_('Vienna',_'Berlin') <= 1 Integer
# 0 <= x_('Vienna',_'Brussels') <= 1 Integer
# 0 <= x_('Vienna',_'Bucharest') <= 1 Integer
# 0 <= x_('Vienna',_'Budapest') <= 1 Integer
# 0 <= x_('Vienna',_'Copenhagen') <= 1 Integer
# 0 <= x_('Vienna',_'Dublin') <= 1 Integer
# 0 <= x_('Vienna',_'Hamburg') <= 1 Integer
# 0 <= x_('Vienna',_'Istanbul') <= 1 Integer
# 0 <= x_('Vienna',_'Kiev') <= 1 Integer
# 0 <= x_('Vienna',_'London') <= 1 Integer
# 0 <= x_('Vienna',_'Madrid') <= 1 Integer
# 0 <= x_('Vienna',_'Milan') <= 1 Integer
# 0 <= x_('Vienna',_'Moscow') <= 1 Integer
# 0 <= x_('Vienna',_'Munich') <= 1 Integer
# 0 <= x_('Vienna',_'Paris') <= 1 Integer
# 0 <= x_('Vienna',_'Prague') <= 1 Integer
# 0 <= x_('Vienna',_'Rome') <= 1 Integer
# 0 <= x_('Vienna',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Vienna',_'Sofia') <= 1 Integer
# 0 <= x_('Vienna',_'Stockholm') <= 1 Integer
# 0 <= x_('Vienna',_'Warsaw') <= 1 Integer
# 0 <= x_('Warsaw',_'Barcelona') <= 1 Integer
# 0 <= x_('Warsaw',_'Belgrade') <= 1 Integer
# 0 <= x_('Warsaw',_'Berlin') <= 1 Integer
# 0 <= x_('Warsaw',_'Brussels') <= 1 Integer
# 0 <= x_('Warsaw',_'Bucharest') <= 1 Integer
# 0 <= x_('Warsaw',_'Budapest') <= 1 Integer
# 0 <= x_('Warsaw',_'Copenhagen') <= 1 Integer
# 0 <= x_('Warsaw',_'Dublin') <= 1 Integer
# 0 <= x_('Warsaw',_'Hamburg') <= 1 Integer
# 0 <= x_('Warsaw',_'Istanbul') <= 1 Integer
# 0 <= x_('Warsaw',_'Kiev') <= 1 Integer
# 0 <= x_('Warsaw',_'London') <= 1 Integer
# 0 <= x_('Warsaw',_'Madrid') <= 1 Integer
# 0 <= x_('Warsaw',_'Milan') <= 1 Integer
# 0 <= x_('Warsaw',_'Moscow') <= 1 Integer
# 0 <= x_('Warsaw',_'Munich') <= 1 Integer
# 0 <= x_('Warsaw',_'Paris') <= 1 Integer
# 0 <= x_('Warsaw',_'Prague') <= 1 Integer
# 0 <= x_('Warsaw',_'Rome') <= 1 Integer
# 0 <= x_('Warsaw',_'Saint_Petersburg') <= 1 Integer
# 0 <= x_('Warsaw',_'Sofia') <= 1 Integer
# 0 <= x_('Warsaw',_'Stockholm') <= 1 Integer
# 0 <= x_('Warsaw',_'Vienna') <= 1 Integer

# %% [markdown]
# Solve it!

# %%
# %time prob.solve()
#prob.solve(GLPK_CMD(options=['--simplex']))
print(LpStatus[prob.status])

# %%
non_zero_edges = [ e for e in x if value(x[e]) != 0 ]

def get_next_site(parent):
    '''helper function to get the next edge'''
    edges = [e for e in non_zero_edges if e[0]==parent]
    for e in edges:
        non_zero_edges.remove(e)
    return edges

# %%
tours = get_next_site('Berlin')
tours = [ [e] for e in tours ]

for t in tours:
    while t[-1][1] !='Berlin':
        t.append(get_next_site(t[-1][1])[-1])

# %% [markdown]
# The optimal route:

# %%
for t in tours:
    print(' -> '.join([ a for a,b in t]+['Berlin']))
# Out:
# Berlin -> Brussels -> Paris -> London -> Dublin -> Hamburg -> Berlin
# Berlin -> Budapest -> Bucharest -> Istanbul -> Sofia -> Belgrade -> Vienna -> Berlin
# Berlin -> Munich -> Milan -> Madrid -> Barcelona -> Rome -> Prague -> Berlin
# Berlin -> Warsaw -> Kiev -> Moscow -> Saint Petersburg -> Stockholm -> Copenhagen -> Berlin

# %% [markdown]
# Calculate total time:

# %%
totalTime = 0;
for t in tours:
    time = 0
    for i in range(0, len(t)):
        time += flighttime.loc[t[i][0], t[i][1]]
#         print(flighttime.loc[t[i][0], t[i][1]])
#     print(time)
    if time > totalTime:
        totalTime = time
print(totalTime)
# Out:
# 1988

# %%
#draw the tours
colors = [np.random.rand(3) for i in range(len(tours))]
for t,c in zip(tours,colors):
    for a,b in t:
        p1,p2 = positions[a], positions[b]
        plt.plot([p1[0],p2[0]],[p1[1],p2[1]], color=c)

#draw the map again
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.title('%d '%K + 'people' if K > 1 else 'person')
plt.xlabel('latitude')
plt.ylabel('longitude')
# plt.gca().axis('off')
plt.show()

# %%
print('Longest time spent:', totalTime, '(min)')
print('Total distance:', value(prob.objective), '(km)')
# Out:
# Longest time spent: 1988 (min)
# Total distance: 15425.019999999999 (km)
